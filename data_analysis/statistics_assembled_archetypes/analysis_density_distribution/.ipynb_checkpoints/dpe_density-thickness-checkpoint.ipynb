# %%
from pathlib import Path
from os import listdir
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def plot_dens_wall_roof_side(dpe, u_bounds, title, renov):
    # Create density and unity density for each data
    x_roof = dpe.adedpe202006_logtype_ph_u.to_numpy()
    len_dens_roof = round((max(x_roof) - min(x_roof))/0.01)+1
    print("len_dens_roof", len_dens_roof)
    x_d_roof = np.linspace(min(x_roof), max(x_roof), len_dens_roof)
    density_roof = sum((abs(xi - x_d_roof) < 0.01) for xi in x_roof)
    unity_density_roof = density_roof / density_roof.sum()

    x_wall = dpe.adedpe202006_logtype_mur_u_ext.to_numpy()
    len_dens_wall = round((max(x_wall) - min(x_wall))/0.01)+1
    print("len_dens_wall",len_dens_wall)
    x_d_wall = np.linspace(min(x_wall), max(x_wall), len_dens_wall)
    density_wall = sum((abs(xi - x_d_wall) < 0.01) for xi in x_wall)
    unity_density_wall = density_wall / density_wall.sum()
    
    df_roof = pd.DataFrame({'x_d_roof':x_d_roof, 
                   'density_roof':density_roof,
                   'unity_density_roof':unity_density_roof,})
    
    df_wall = pd.DataFrame({'x_d_wall':x_d_wall,
                   'density_wall':density_wall,
                   'unity_density_wall':unity_density_wall,
                  })

    #plot 
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12, 4))
    fig.suptitle(title, y=1.05, fontweight = "heavy")
    fig.supxlabel('Valeur U [W/(m².K)]')

    # U-value boundaries
    uw_min = u_bounds[0]
    uw_max = u_bounds[1]
    uph_min = u_bounds[2]
    uph_max = u_bounds[3]

    # formats
    format_roof = {"color":"darkslateblue",  "label":'toit'}
    format_wall = {"color":"darkslateblue",  "label":'mur'}
    format_vline = {"linewidth":2, "color":'r', "alpha":0.5, "linestyle":"--"}
    offset = 0.1  
  
    
    # plot wall
    ax1.set_title(f'Mur extérieur\nvert: {renov["perc_below_lim_wall"]:.1f}%  -  '
                                  f'jaune: {renov["perc_within_lim_wall"]:.1f}%  -  '
                                  f'rouge:{renov["perc_above_lim_wall"]:.1f}%')
    ax1.fill_between(x_d_wall, unity_density_wall, **format_wall)
    ax1.axvspan(0, uw_min, alpha=0.15, color='green')
    ax1.axvspan(uw_min, uw_max, alpha=0.15, color='gold')
    ax1.axvspan(uw_max, x_wall.max(), alpha=0.15, color='red')

    #plot roof
    ax2.set_title(f'Toit\nvert: {renov["perc_below_lim_roof"]:.1f}%  -  '
                          f'jaune: {renov["perc_within_lim_wall"]:.1f}%  -  '
                          f'rouge: {renov["perc_above_lim_roof"]:.1f}%')
    ax2.fill_between(x_d_roof, unity_density_roof, **format_roof)
    ax2.axvspan(0, uph_min, alpha=0.15, color='green')
    ax2.axvspan(uph_min, uph_max, alpha=0.15, color='gold')
    ax2.axvspan(uph_max, x_roof.max(), alpha=0.15, color='red')
    plt.tight_layout

    plt.show()
    return fig, df_roof, df_wall

# %%
def plot_dens_wall_roof_legend(dpe, u_bounds, title, renov):
    # Create density and unity density for each data
    x_roof = dpe.adedpe202006_logtype_ph_u.to_numpy()
    len_dens_roof = round((max(x_roof) - min(x_roof))/0.01)+1
    print("len_dens_roof", len_dens_roof)
    x_d_roof = np.linspace(min(x_roof), max(x_roof), len_dens_roof)
    density_roof = sum((abs(xi - x_d_roof) < 0.01) for xi in x_roof)
    unity_density_roof = density_roof / density_roof.sum()

    x_wall = dpe.adedpe202006_logtype_mur_u_ext.to_numpy()
    len_dens_wall = round((max(x_wall) - min(x_wall))/0.01)+1
    print("len_dens_wall",len_dens_wall)
    x_d_wall = np.linspace(min(x_wall), max(x_wall), len_dens_wall)
    density_wall = sum((abs(xi - x_d_wall) < 0.01) for xi in x_wall)
    unity_density_wall = density_wall / density_wall.sum()
    
    df_roof = pd.DataFrame({'x_d_roof':x_d_roof, 
                   'density_roof':density_roof,
                   'unity_density_roof':unity_density_roof,})
    
    df_wall = pd.DataFrame({'x_d_wall':x_d_wall,
                   'density_wall':density_wall,
                   'unity_density_wall':unity_density_wall,
                  })

    #plot 
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(12, 4))
    fig.suptitle(title, y=1.06, fontweight = "heavy")
    fig.supxlabel('Valeur U [W/(m².K)]')

    # U-value boundaries
    uw_min = u_bounds[0]
    uw_max = u_bounds[1]
    uph_min = u_bounds[2]
    uph_max = u_bounds[3]

    # formats
    format_roof = {"color":"darkslateblue",  }
    format_wall = {"color":"darkslateblue",  }
    format_vline = {"linewidth":2, "color":'r', "alpha":0.5, "linestyle":"--"}
    format_legend= {"bbox_to_anchor":(0.1, 1),
                    "ncol":3, 
                    "fancybox":True, 
                    "shadow":True,  
                    "borderaxespad":0.}
 
    
    # plot wall
    ax1.set_title('Mur extérieur', y =1.09)
    ax1.fill_between(x_d_wall, unity_density_wall, **format_wall)
    ax1.axvspan(0, uw_min, alpha=0.15, color='green', label=f'{renov["perc_below_lim_wall"]:.0f}%' + r'$< U_{min} \leq$')
    ax1.axvspan(uw_min, uw_max, alpha=0.15, color='gold', label=rf'{renov["perc_within_lim_wall"]:.0f}%   ≤ U_max')
    ax1.axvspan(uw_max, x_wall.max(), alpha=0.15, color='red', label=rf' {renov["perc_above_lim_wall"]:.0f}%')

    #plot roof
    ax2.set_title('Toit', y =1.09)        
    ax2.fill_between(x_d_roof, unity_density_roof, **format_roof)
    ax2.axvspan(0, uph_min, alpha=0.15, color='green', label=f'{renov["perc_below_lim_roof"]:.0f}%' + r'$< U_{min} \leq$')
    ax2.axvspan(uph_min, uph_max, alpha=0.15, color='gold', label=rf'{renov["perc_within_lim_roof"]:.0f}%   ≤ U_max')
    ax2.axvspan(uph_max, x_roof.max(), alpha=0.15, color='red', label=rf' {renov["perc_above_lim_roof"]:.0f}%')
    format_legend= {"bbox_to_anchor":(0.0001, 1),
                    "ncol":3, 
                    "fancybox":True, 
                    "shadow":True,  
                    "borderaxespad":0.}
    ax1.legend(**format_legend)

    ax2.legend(**format_legend)
#     plt.xlim(right=2.5)
    ax1.set_xlim((0,2.52))
    ax2.set_xlim((0,2.52))
    
    plt.show()
    
    return fig, df_roof, df_wall

# %%
source_folder = Path(r"U:\WORK\assembled_same_U\with_complete_dpe_data\all")
save_fig_folder = Path(r"U:\WORK\code_gpd\data_analysis\analysis_assembled_archetypes\dpe_density_plots\plots_wall_roof")

# %% [markdown]
# ## Density + boundary -  n_dpe > 300

# %%
dan_bound_path = r"U:\WORK\code_gpd\data_analysis\notebooks_danube\dispositifs_study\danube_U_values\Danube_with_U_bound_association.xlsx"
dan = pd.read_excel(dan_bound_path, index_col=0)
dan.head()
# Out:
#                USAGE NOM_TYPOLOGIE PERIODE                      TERRITOIRE  \
# 0  BATIMENT AGRICOLE            BA      P1                          FRANCE
# 1  BATIMENT AGRICOLE            BA      P1             FRANCE_BOIS_ARDOISE
# 2  BATIMENT AGRICOLE            BA      P1               FRANCE_BOIS_TUILE
# 3  BATIMENT AGRICOLE            BA      P1             FRANCE_BRIQUE_TUILE
# 4  BATIMENT AGRICOLE            BA      P1  FRANCE_PIERRE_CALCAIRE_ARDOISE
#
#       DISPOSITIF_M1     PORTEUR_M1  EP_PORTEUR_M1 ISOLANT_M1  EP_ISOLANT_M1  \
# 0   PAV_M_P1_TBr_br  BRIQUE PLEINE             60        NON              0
# 1   PAV_M_P1_TBo-bo           BOIS             50         IR              0
# 2   PAV_M_P1_TBo-bo           BOIS             50         IR              0
# 3   PAV_M_P1_TBr_br  BRIQUE PLEINE             60        NON              0
# 4  PAV_M_P1_TPi_Cal       CALCAIRE             80        NON              0
#
#   REVETEMENT_INT_M1  ...  Uph_min Uph_max  Uw_0 Uw_min Uw_max  \
# 0            ENDUIT  ...      1.2     2.5  1.35   1.35    2.5
# 1               NON  ...      1.2     2.5  0.80   0.80    2.5
# 2               NON  ...      1.2     2.5  0.80   0.80    2.5
# 3            ENDUIT  ...      1.2     2.5  1.35   1.35    2.5
# 4               NON  ...      1.2     2.5  1.50   1.50    2.5
#
#                                            archetype one_one  two_one  \
# 0                     P1-BA-BATIMENT AGRICOLE-FRANCE     NaN      NaN
# 1        P1-BA-BATIMENT AGRICOLE-FRANCE_BOIS_ARDOISE     NaN      NaN
# 2          P1-BA-BATIMENT AGRICOLE-FRANCE_BOIS_TUILE     NaN      NaN
# 3        P1-BA-BATIMENT AGRICOLE-FRANCE_BRIQUE_TUILE     NaN      NaN
# 4  P1-BA-BATIMENT AGRICOLE-FRANCE_PIERRE_CALCAIRE...     NaN      NaN
#
#   many_one  fichier
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
# [5 rows x 79 columns]

# %%
df_anlz = dan[dan['fichier'].notnull()]

file_gb = df_anlz[['archetype', 'fichier', 
                     'Uph_min', 
                     'Uph_max', 
                     'Uw_min', 
                     'Uw_max',
                    ]].groupby("fichier")

bounds = file_gb.agg({'Uw_min' : np.mean,
            'Uw_max' : np.mean,
            'Uph_min' : np.mean,
            'Uph_max' : np.mean})
print(len(bounds))
bounds
# Out:
# 24
#                                                       Uw_min    Uw_max  \
# fichier
# dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUIL...  0.800000  2.500000
# dpe_all3-len_1074-P1-I-HABITAT-FRANCE_TERRE_TUI...  1.500000  2.500000
# dpe_all3-len_11838-P4-I-HABITAT-FRANCE-toit.csv     0.503067  0.890000
# dpe_all3-len_13728-P3-I-HABITAT-FRANCE-toit.csv     0.800000  1.647059
# dpe_all3-len_141836-P5-P-HABITAT-FRANCE-toit.csv    0.450000  0.560000
# dpe_all3-len_144873-P4-P-HABITAT-FRANCE-toit.csv    0.571429  0.890000
# dpe_all3-len_185528-P3-P-HABITAT-FRANCE-toit.csv    0.500000  1.110000
# dpe_all3-len_2141-P1-P-HABITAT-FRANCE_BOIS_TUIL...  0.800000  2.500000
# dpe_all3-len_214978-P6-P-HABITAT-FRANCE-toit.csv    0.350000  0.470000
# dpe_all3-len_2343-P1-P-HABITAT-FRANCE_TERRE_TUI...  1.550000  2.500000
# dpe_all3-len_23434-P5-I-HABITAT-FRANCE-toit.csv     0.450000  0.560000
# dpe_all3-len_24633-P1-I-HABITAT-FRANCE_PIERRE-r...  1.500000  2.500000
# dpe_all3-len_31734-P6-I-HABITAT-FRANCE-toit.csv     0.351515  0.470000
# dpe_all3-len_320-P2-I-TERTIAIRE-FRANCE-nati.csv     2.500000  2.900000
# dpe_all3-len_34181-P1-P-HABITAT-FRANCE_BRIQUE-t...  1.350000  2.500000
# dpe_all3-len_349662-P2-P-HABITAT-FRANCE-toit.csv    2.000000  2.500000
# dpe_all3-len_364-P6-I-TERTIAIRE-FRANCE-nati.csv     0.360000  0.470000
# dpe_all3-len_48162-P7-P-HABITAT-FRANCE-toit.csv     0.229508  0.400000
# dpe_all3-len_49532-P2-I-HABITAT-FRANCE-toit.csv     2.500000  2.800000
# dpe_all3-len_52731-P1-P-HABITAT-FRANCE_PIERRE-r...  1.500000  2.500000
# dpe_all3-len_634-P2-I-COMMERCE-FRANCE-nati.csv      2.500000  2.900000
# dpe_all3-len_9137-P7-I-HABITAT-FRANCE-toit.csv      0.220930  0.400000
# dpe_all3-len_916-P1-I-COMMERCE-FRANCE-nati.csv      1.500000  2.500000
# dpe_all3-len_9405-P1-I-HABITAT-FRANCE_BRIQUE-to...  1.350000  2.500000
#
#                                                      Uph_min  Uph_max
# fichier
# dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUIL...  1.200000  2.50000
# dpe_all3-len_1074-P1-I-HABITAT-FRANCE_TERRE_TUI...  1.200000  2.50000
# dpe_all3-len_11838-P4-I-HABITAT-FRANCE-toit.csv     0.260870  0.33000
# dpe_all3-len_13728-P3-I-HABITAT-FRANCE-toit.csv     0.400000  2.30000
# dpe_all3-len_141836-P5-P-HABITAT-FRANCE-toit.csv    0.218182  0.30000
# dpe_all3-len_144873-P4-P-HABITAT-FRANCE-toit.csv    0.260870  0.33000
# dpe_all3-len_185528-P3-P-HABITAT-FRANCE-toit.csv    0.400000  2.30000
# dpe_all3-len_2141-P1-P-HABITAT-FRANCE_BOIS_TUIL...  1.200000  2.50000
# dpe_all3-len_214978-P6-P-HABITAT-FRANCE-toit.csv    0.171429  0.30000
# dpe_all3-len_2343-P1-P-HABITAT-FRANCE_TERRE_TUI...  1.200000  2.50000
# dpe_all3-len_23434-P5-I-HABITAT-FRANCE-toit.csv     0.218182  0.30000
# dpe_all3-len_24633-P1-I-HABITAT-FRANCE_PIERRE-r...  1.200000  2.50000
# dpe_all3-len_31734-P6-I-HABITAT-FRANCE-toit.csv     0.171429  0.30000
# dpe_all3-len_320-P2-I-TERTIAIRE-FRANCE-nati.csv     2.500000  2.50000
# dpe_all3-len_34181-P1-P-HABITAT-FRANCE_BRIQUE-t...  1.200000  2.50000
# dpe_all3-len_349662-P2-P-HABITAT-FRANCE-toit.csv    1.200000  2.50000
# dpe_all3-len_364-P6-I-TERTIAIRE-FRANCE-nati.csv     0.270000  0.31746
# dpe_all3-len_48162-P7-P-HABITAT-FRANCE-toit.csv     0.120000  0.25000
# dpe_all3-len_49532-P2-I-HABITAT-FRANCE-toit.csv     1.200000  2.50000
# dpe_all3-len_52731-P1-P-HABITAT-FRANCE_PIERRE-r...  1.200000  2.50000
# dpe_all3-len_634-P2-I-COMMERCE-FRANCE-nati.csv      2.500000  2.50000
# dpe_all3-len_9137-P7-I-HABITAT-FRANCE-toit.csv      0.120000  0.25000
# dpe_all3-len_916-P1-I-COMMERCE-FRANCE-nati.csv      1.200000  2.50000
# dpe_all3-len_9405-P1-I-HABITAT-FRANCE_BRIQUE-to...  1.200000  2.50000

# %% [markdown]
# ### New

# %%
def define_boundaries(dpe,bounds, csv):
    uw_min  = bounds.loc[csv, "Uw_min"]
    uw_max  = bounds.loc[csv, "Uw_max"]
    uph_min  = bounds.loc[csv, "Uph_min"]
    uph_max  = bounds.loc[csv, "Uph_max"]
    u_bounds = (uw_min, uw_max, uph_min, uph_max)
    # wall perc
    below_bound_wall = dpe[dpe["adedpe202006_logtype_mur_u_ext"] < uw_min]
    within_bound_wall = dpe[(dpe["adedpe202006_logtype_mur_u_ext"] >= uw_min) & 
                                (dpe["adedpe202006_logtype_mur_u_ext"] <= uw_max)] 
    above_bound_wall = dpe[dpe["adedpe202006_logtype_mur_u_ext"] > uw_max]
    # roof perc
    below_bound_roof = dpe[dpe["adedpe202006_logtype_ph_u"] < uph_min]
    within_bound_roof = dpe[(dpe["adedpe202006_logtype_ph_u"] >= uph_min) & 
                                    (dpe["adedpe202006_logtype_ph_u"] <= uph_max)] 
    above_bound_roof = dpe[dpe["adedpe202006_logtype_ph_u"] > uph_max]
    
    tables_wall = (below_bound_wall, within_bound_wall, above_bound_wall)
    tables_roof = (below_bound_roof, within_bound_roof, above_bound_roof)
    
    return u_bounds, tables_wall, tables_roof

# %%
def describe_renovation(tables_wall, tables_roof):

    # percentages --------------------------------------------------------
    perc_wall = [len(table) / len(dpe) * 100 for table in tables_wall]
    perc_roof = [len(table) / len(dpe) * 100 for table in tables_roof]
    
    renov_wall_perc = { "perc_below_lim_wall" : perc_wall[0],
                        "perc_within_lim_wall" : perc_wall[1],
                        "perc_above_lim_wall" : perc_wall[2],}
    renov_roof_perc = { "perc_below_lim_roof" : perc_roof[0],
                        "perc_within_lim_roof" : perc_roof[1],
                        "perc_above_lim_roof" : perc_roof[2]}
    
    renov_wall_perc = { k : round(v, 1) for (k,v) in renov_wall_perc.items()}  
    renov_roof_perc = { k : round(v, 1) for (k,v) in renov_roof_perc.items()}  
    
    # statistics ------------------------------------------------------------
    renov_wall = tables_wall[0]
    renov_roof = tables_roof[0]
    describe_index = ['count', 'mean', 'std', 'min', 'Q1', 'Q2', 'Q3', 'max']

    # wall
    renov_wall_describe = renov_wall.adedpe202006_logtype_mur_u_ext.describe()
    renov_wall_describe.index = describe_index
    renov_wall_stat = {"renov_wall_" + k : round(v, 3) for (k,v) in renov_wall_describe.to_dict().items()}  
    
    # roof
    renov_roof_describe = renov_roof.adedpe202006_logtype_ph_u.describe()
    renov_roof_describe.index = describe_index
    renov_roof_stat = {"renov_roof_" + k : round(v, 3) for (k,v) in renov_roof_describe.to_dict().items()}   
    
    resume_renov =  renov_wall_perc | renov_wall_stat | renov_roof_perc | renov_roof_stat
    
    return resume_renov

# %%
def describe_distribution(dpe):
    describe_index = ['count', 'mean', 'std', 'min', 'Q1', 'Q2', 'Q3', 'max']
    # wall
    dist_wall_describe = dpe.adedpe202006_logtype_mur_u_ext.describe()
    dist_wall_describe.index = describe_index
    dist_wall_stat = {"dist_wall_" + k : round(v, 3) for (k,v) in dist_wall_describe.to_dict().items()}  
    
    # roof
    dist_roof_describe = dpe.adedpe202006_logtype_ph_u.describe()
    dist_roof_describe.index = describe_index
    dist_roof_stat = {"dist_roof_" + k : round(v, 3) for (k,v) in dist_roof_describe.to_dict().items()}   
    
    resume_distribution =  dist_wall_stat | dist_roof_stat
    
    return resume_distribution

# %%
summary_data = {}
for csv in bounds.index:   
    path = source_folder / csv
    root_name = "-".join(path.stem.split("-")[2:-1]) 
    print("\n", root_name)
    print(csv)
    dpe = pd.read_csv(path)
    
    dpe

    # boundaries
    u_bounds, tables_wall, tables_roof = define_boundaries(dpe, bounds, csv)

    # percentage
    resume_distribution = describe_distribution(dpe)
    resume_renovation = describe_renovation(tables_wall, tables_roof)
    resume = resume_distribution | resume_renovation
    summary_data[csv] = resume

    # plot
    figure, df_roof, df_wall = plot_dens_wall_roof_legend(dpe, u_bounds, root_name, resume_renovation)
    save_fig_name = "Dens_" + root_name + ".png"
    figure.savefig(save_fig_folder / "side_by_side" / save_fig_name)
# Out:
#  P1-I-HABITAT-FRANCE_BOIS_TUILE
# dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUILE-uniq.csv
# len_dens_roof 245
# len_dens_wall 241
#  P1-I-HABITAT-FRANCE_TERRE_TUILE
# dpe_all3-len_1074-P1-I-HABITAT-FRANCE_TERRE_TUILE-uniq.csv
# len_dens_roof 243
# len_dens_wall 241
#  P4-I-HABITAT-FRANCE
# dpe_all3-len_11838-P4-I-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (127,128,130,172,299,300,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 295
# len_dens_wall 281
#  P3-I-HABITAT-FRANCE
# dpe_all3-len_13728-P3-I-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (127,128,130,172,299,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 352
# len_dens_wall 299
#  P5-P-HABITAT-FRANCE
# dpe_all3-len_141836-P5-P-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,50,51,52,53,54,55,56,57,75,127,128,130,172,199,205,222,248,250,251,299,301,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 246
# len_dens_wall 257
#  P4-P-HABITAT-FRANCE
# dpe_all3-len_144873-P4-P-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,37,53,54,75,127,128,130,172,199,248,250,251,299,300,301,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 246
# len_dens_wall 346
#  P3-P-HABITAT-FRANCE
# dpe_all3-len_185528-P3-P-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,37,50,51,52,53,54,55,56,57,75,127,128,130,172,199,205,222,248,250,251,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 413
# len_dens_wall 296
#  P1-P-HABITAT-FRANCE_BOIS_TUILE
# dpe_all3-len_2141-P1-P-HABITAT-FRANCE_BOIS_TUILE-uniq.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (53,54,75,199,248,250,251,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 245
# len_dens_wall 242
#  P6-P-HABITAT-FRANCE
# dpe_all3-len_214978-P6-P-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,37,50,51,52,53,54,55,56,57,75,127,128,130,172,199,205,222,248,250,251,299,301,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 246
# len_dens_wall 496
#  P1-P-HABITAT-FRANCE_TERRE_TUILE
# dpe_all3-len_2343-P1-P-HABITAT-FRANCE_TERRE_TUILE-uniq.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,75,172,248,251,303) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 245
# len_dens_wall 243
#  P5-I-HABITAT-FRANCE
# dpe_all3-len_23434-P5-I-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (127,128,130,155,172,299,300,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 295
# len_dens_wall 266
#  P1-I-HABITAT-FRANCE_PIERRE
# dpe_all3-len_24633-P1-I-HABITAT-FRANCE_PIERRE-rock.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (127,128,130,133,155,172,295,299,300,301,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 418
# len_dens_wall 338
#  P6-I-HABITAT-FRANCE
# dpe_all3-len_31734-P6-I-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (53,54,127,128,130,299,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 246
# len_dens_wall 296
#  P2-I-TERTIAIRE-FRANCE
# dpe_all3-len_320-P2-I-TERTIAIRE-FRANCE-nati.csv
# len_dens_roof 281
# len_dens_wall 194
#  P1-P-HABITAT-FRANCE_BRIQUE
# dpe_all3-len_34181-P1-P-HABITAT-FRANCE_BRIQUE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,53,54,75,172,248,299,301,303) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 270
# len_dens_wall 285
#  P2-P-HABITAT-FRANCE
# dpe_all3-len_349662-P2-P-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,37,50,51,52,53,54,55,56,57,75,127,128,130,155,172,199,205,222,248,250,251,299,300,301,302,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 436
# len_dens_wall 431
#  P6-I-TERTIAIRE-FRANCE
# dpe_all3-len_364-P6-I-TERTIAIRE-FRANCE-nati.csv
# len_dens_roof 241
# len_dens_wall 237
#  P7-P-HABITAT-FRANCE
# dpe_all3-len_48162-P7-P-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (75,127,128,130,199,248,299,301,303,304) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 246
# len_dens_wall 426
#  P2-I-HABITAT-FRANCE
# dpe_all3-len_49532-P2-I-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (8,9,50,51,52,53,54,55,56,57,115,127,128,130,155,172,198,205,222,295,299,300,301,307) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 416
# len_dens_wall 416
#  P1-P-HABITAT-FRANCE_PIERRE
# dpe_all3-len_52731-P1-P-HABITAT-FRANCE_PIERRE-rock.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (75,127,128,130,172,248,299,300,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 458
# len_dens_wall 247
#  P2-I-COMMERCE-FRANCE
# dpe_all3-len_634-P2-I-COMMERCE-FRANCE-nati.csv
# len_dens_roof 243
# len_dens_wall 239
#  P7-I-HABITAT-FRANCE
# dpe_all3-len_9137-P7-I-HABITAT-FRANCE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (127,128,130,299,300,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 245
# len_dens_wall 245
#  P1-I-COMMERCE-FRANCE
# dpe_all3-len_916-P1-I-COMMERCE-FRANCE-nati.csv
# len_dens_roof 356
# len_dens_wall 246
#  P1-I-HABITAT-FRANCE_BRIQUE
# dpe_all3-len_9405-P1-I-HABITAT-FRANCE_BRIQUE-toit.csv
# C:\Users\ldecarva\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (155,172,299,301) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# len_dens_roof 329
# len_dens_wall 257

# %%
pd.DataFrame(summary_data).T.reset_index()
# Out:
#                                                index  dist_wall_count  \
# 0  dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUI...           1010.0
# 1  dpe_all3-len_1074-P1-I-HABITAT-FRANCE_TERRE_TU...           1074.0
#
#    dist_wall_mean  dist_wall_std  dist_wall_min  dist_wall_Q1  dist_wall_Q2  \
# 0           0.809          0.681            0.1          0.34           0.4
# 1           0.779          0.671            0.1          0.33           0.4
#
#    dist_wall_Q3  dist_wall_max  dist_roof_count  ...  perc_within_lim_roof  \
# 0          1.50            2.5           1010.0  ...                  32.6
# 1          0.98            2.5           1074.0  ...                  27.5
#
#    perc_above_lim_roof  renov_roof_count  renov_roof_mean  renov_roof_std  \
# 0                  0.0             681.0            0.255           0.135
# 1                  0.0             779.0            0.234           0.118
#
#    renov_roof_min  renov_roof_Q1  renov_roof_Q2  renov_roof_Q3  renov_roof_max
# 0            0.06           0.18           0.20           0.30            1.11
# 1            0.08           0.17           0.19           0.25            1.11
#
# [2 rows x 39 columns]

# %%
df_resume = pd.DataFrame(summary_data).T.reset_index()
df_resume.rename(columns={"index":"fichier"}, inplace=True)
df_resume.head()
# Out:
#                                              fichier  dist_wall_count  \
# 0  dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUI...           1010.0
# 1  dpe_all3-len_1074-P1-I-HABITAT-FRANCE_TERRE_TU...           1074.0
# 2    dpe_all3-len_11838-P4-I-HABITAT-FRANCE-toit.csv          11838.0
# 3    dpe_all3-len_13728-P3-I-HABITAT-FRANCE-toit.csv          13728.0
# 4   dpe_all3-len_141836-P5-P-HABITAT-FRANCE-toit.csv         141836.0
#
#    dist_wall_mean  dist_wall_std  dist_wall_min  dist_wall_Q1  dist_wall_Q2  \
# 0           0.809          0.681           0.10          0.34          0.40
# 1           0.779          0.671           0.10          0.33          0.40
# 2           0.683          0.420           0.06          0.40          0.61
# 3           0.972          0.600           0.05          0.44          0.84
# 4           0.456          0.231           0.05          0.35          0.42
#
#    dist_wall_Q3  dist_wall_max  dist_roof_count  ...  perc_within_lim_roof  \
# 0          1.50           2.50           1010.0  ...                  32.6
# 1          0.98           2.50           1074.0  ...                  27.5
# 2          0.80           2.86          11838.0  ...                  15.4
# 3          1.18           3.03          13728.0  ...                  27.3
# 4          0.47           2.61         141836.0  ...                  39.8
#
#    perc_above_lim_roof  renov_roof_count  renov_roof_mean  renov_roof_std  \
# 0                  0.0             681.0            0.255           0.135
# 1                  0.0             779.0            0.234           0.118
# 2                 59.5            2970.0            0.193           0.044
# 3                 41.7            4256.0            0.231           0.073
# 4                 10.2           70868.0            0.168           0.029
#
#    renov_roof_min  renov_roof_Q1  renov_roof_Q2  renov_roof_Q3  renov_roof_max
# 0            0.06           0.18           0.20           0.30            1.11
# 1            0.08           0.17           0.19           0.25            1.11
# 2            0.06           0.17           0.19           0.24            0.26
# 3            0.06           0.18           0.22           0.30            0.39
# 4            0.05           0.15           0.18           0.19            0.21
#
# [5 rows x 39 columns]

# %%
df_anlz_complete = pd.merge(df_anlz, df_resume, how="left", on="fichier", copy=False)
df_anlz_complete.columns
# Out:
# Index(['USAGE', 'NOM_TYPOLOGIE', 'PERIODE', 'TERRITOIRE', 'DISPOSITIF_M1',
#        'PORTEUR_M1', 'EP_PORTEUR_M1', 'ISOLANT_M1', 'EP_ISOLANT_M1',
#        'REVETEMENT_INT_M1',
#        ...
#        'perc_within_lim_roof', 'perc_above_lim_roof', 'renov_roof_count',
#        'renov_roof_mean', 'renov_roof_std', 'renov_roof_min', 'renov_roof_Q1',
#        'renov_roof_Q2', 'renov_roof_Q3', 'renov_roof_max'],
#       dtype='object', length=117)

# %%
df_anlz_complete.head()
# Out:
#       USAGE NOM_TYPOLOGIE PERIODE                      TERRITOIRE  \
# 0  COMMERCE             I      P1                          FRANCE
# 1   HABITAT             I      P1               FRANCE_BOIS_TUILE
# 2   HABITAT             I      P1             FRANCE_BRIQUE_TUILE
# 3   HABITAT             I      P1  FRANCE_PIERRE_CALCAIRE_ARDOISE
# 4   HABITAT             I      P1    FRANCE_PIERRE_CALCAIRE_TUILE
#
#       DISPOSITIF_M1     PORTEUR_M1  EP_PORTEUR_M1 ISOLANT_M1  EP_ISOLANT_M1  \
# 0      IMM_M_P1_TPI         PIERRE             90        NON              0
# 1   PAV_M_P1_TBo-bo           BOIS             50         IR              0
# 2   IMM_M_P1_TBr_br  BRIQUE PLEINE             60        NON              0
# 3  PAV_M_P1_TPi_Cal       CALCAIRE             80        NON              0
# 4  PAV_M_P1_TPi_Cal       CALCAIRE             80        NON              0
#
#   REVETEMENT_INT_M1  ...  perc_within_lim_roof perc_above_lim_roof  \
# 0               NON  ...                  26.6                 0.1
# 1               NON  ...                  32.6                 0.0
# 2            ENDUIT  ...                  37.4                 0.0
# 3               NON  ...                  42.0                 0.0
# 4               NON  ...                  42.0                 0.0
#
#    renov_roof_count renov_roof_mean renov_roof_std  renov_roof_min  \
# 0             671.0           0.265          0.156            0.06
# 1             681.0           0.255          0.135            0.06
# 2            5884.0           0.272          0.152            0.05
# 3           14273.0           0.275          0.158            0.06
# 4           14273.0           0.275          0.158            0.06
#
#   renov_roof_Q1  renov_roof_Q2 renov_roof_Q3  renov_roof_max
# 0          0.18           0.20          0.30            1.07
# 1          0.18           0.20          0.30            1.11
# 2          0.19           0.23          0.32            1.11
# 3          0.18           0.23          0.32            1.18
# 4          0.18           0.23          0.32            1.18
#
# [5 rows x 117 columns]

# %% [markdown]
# ### Corresponding thickness

# %%
from IPython.display import Image
Image(filename = "e_formula.png", width=200, )

# %%
# e = ( 1/U - 1/U_0) * 0.04
# Whole distribution
# wall
df_anlz_complete["EP_ISOL_M1_dist_med"] = (( 1 / df_anlz_complete.dist_wall_Q2 - 1 / df_anlz_complete.Uw_0) * 0.04 * 100).round()
df_anlz_complete["EP_ISOL_M1_dist_moy"] = (( 1 / df_anlz_complete.dist_wall_mean - 1 / df_anlz_complete.Uw_0) * 0.04 * 100).round()
# roof
df_anlz_complete["EP_ISOL_T1_dist_moy"] = (( 1 / df_anlz_complete.dist_roof_mean - 1 / df_anlz_complete.Uph_0_moy) * 0.04 * 100).round()
df_anlz_complete["EP_ISOL_T1_dist_med"] = (( 1 / df_anlz_complete.dist_roof_Q2 - 1 / df_anlz_complete.Uph_0_moy) * 0.04 * 100).round()

# Renovation
# wall
df_anlz_complete["EP_ISOL_M1_renov_med"] = (( 1 / df_anlz_complete.renov_wall_Q2 - 1 / df_anlz_complete.Uw_0) * 0.04 * 100).round()
df_anlz_complete["EP_ISOL_M1_renov_moy"] = (( 1 / df_anlz_complete.renov_wall_mean - 1 / df_anlz_complete.Uw_0) * 0.04 * 100).round()
# roof
df_anlz_complete["EP_ISOL_T1_renov_moy"] = (( 1 / df_anlz_complete.renov_roof_mean - 1 / df_anlz_complete.Uph_0_moy) * 0.04 * 100).round()
df_anlz_complete["EP_ISOL_T1_renov_med"] = (( 1 / df_anlz_complete.renov_roof_Q2 - 1 / df_anlz_complete.Uph_0_moy) * 0.04 * 100).round()

# %%
df_anlz_complete
# Out:
#         USAGE NOM_TYPOLOGIE PERIODE                        TERRITOIRE  \
# 0    COMMERCE             I      P1                            FRANCE
# 1     HABITAT             I      P1                 FRANCE_BOIS_TUILE
# 2     HABITAT             I      P1               FRANCE_BRIQUE_TUILE
# 3     HABITAT             I      P1    FRANCE_PIERRE_CALCAIRE_ARDOISE
# 4     HABITAT             I      P1      FRANCE_PIERRE_CALCAIRE_TUILE
# 5     HABITAT             I      P1       FRANCE_PIERRE_CALCAIRE_ZINC
# 6     HABITAT             I      P1         FRANCE_PIERRE_GALET_TUILE
# 7     HABITAT             I      P1        FRANCE_PIERRE_GNEISS_TUILE
# 8     HABITAT             I      P1     FRANCE_PIERRE_GRANITE_ARDOISE
# 9     HABITAT             I      P1       FRANCE_PIERRE_GRANITE_TUILE
# 10    HABITAT             I      P1        FRANCE_PIERRE_GRES_ARDOISE
# 11    HABITAT             I      P1          FRANCE_PIERRE_GRES_TUILE
# 12    HABITAT             I      P1      FRANCE_PIERRE_MEULIERE_TUILE
# 13    HABITAT             I      P1       FRANCE_PIERRE_SCHISTE_TUILE
# 14    HABITAT             I      P1  FRANCE_PIERRE_VOLCANIQUE_ARDOISE
# 15    HABITAT             I      P1                FRANCE_TERRE_TUILE
# 16    HABITAT             P      P1                 FRANCE_BOIS_TUILE
# 17    HABITAT             P      P1               FRANCE_BRIQUE_TUILE
# 18    HABITAT             P      P1      FRANCE_PIERRE_CALCAIRE_TUILE
# 19    HABITAT             P      P1       FRANCE_PIERRE_CALCAIRE_ZINC
# 20    HABITAT             P      P1         FRANCE_PIERRE_GALET_TUILE
# 21    HABITAT             P      P1        FRANCE_PIERRE_GNEISS_TUILE
# 22    HABITAT             P      P1     FRANCE_PIERRE_GRANITE_ARDOISE
# 23    HABITAT             P      P1       FRANCE_PIERRE_GRANITE_TUILE
# 24    HABITAT             P      P1        FRANCE_PIERRE_GRES_ARDOISE
# 25    HABITAT             P      P1          FRANCE_PIERRE_GRES_TUILE
# 26    HABITAT             P      P1      FRANCE_PIERRE_MEULIERE_TUILE
# 27    HABITAT             P      P1       FRANCE_PIERRE_SCHISTE_TUILE
# 28    HABITAT             P      P1  FRANCE_PIERRE_VOLCANIQUE_ARDOISE
# 29    HABITAT             P      P1                FRANCE_TERRE_TUILE
# 30   COMMERCE             I      P2                            FRANCE
# 31    HABITAT             I      P2                    FRANCE_ARDOISE
# 32    HABITAT             I      P2                      FRANCE_TUILE
# 33  TERTIAIRE             I      P2                            FRANCE
# 34    HABITAT             P      P2                    FRANCE_ARDOISE
# 35    HABITAT             P      P2                      FRANCE_TUILE
# 36    HABITAT             I      P3                    FRANCE_ARDOISE
# 37    HABITAT             I      P3                      FRANCE_TUILE
# 38    HABITAT             P      P3                    FRANCE_ARDOISE
# 39    HABITAT             P      P3                      FRANCE_TUILE
# 40    HABITAT             I      P4                    FRANCE_ARDOISE
# 41    HABITAT             I      P4                      FRANCE_TUILE
# 42    HABITAT             P      P4                    FRANCE_ARDOISE
# 43    HABITAT             P      P4                      FRANCE_TUILE
# 44    HABITAT             I      P5                    FRANCE_ARDOISE
# 45    HABITAT             I      P5                      FRANCE_TUILE
# 46    HABITAT             P      P5                    FRANCE_ARDOISE
# 47    HABITAT             P      P5                      FRANCE_TUILE
# 48    HABITAT             I      P6                    FRANCE_ARDOISE
# 49    HABITAT             I      P6                      FRANCE_TUILE
# 50  TERTIAIRE             I      P6                            FRANCE
# 51    HABITAT             P      P6                    FRANCE_ARDOISE
# 52    HABITAT             P      P6                      FRANCE_TUILE
# 53    HABITAT             I      P7                    FRANCE_ARDOISE
# 54    HABITAT             I      P7                      FRANCE_TUILE
# 55    HABITAT             P      P7                    FRANCE_ARDOISE
# 56    HABITAT             P      P7                      FRANCE_TUILE
#
#           DISPOSITIF_M1           PORTEUR_M1  EP_PORTEUR_M1 ISOLANT_M1  \
# 0          IMM_M_P1_TPI               PIERRE             90        NON
# 1       PAV_M_P1_TBo-bo                 BOIS             50         IR
# 2       IMM_M_P1_TBr_br        BRIQUE PLEINE             60        NON
# 3      PAV_M_P1_TPi_Cal             CALCAIRE             80        NON
# 4      PAV_M_P1_TPi_Cal             CALCAIRE             80        NON
# 5      PAV_M_P1_TPi_Cal             CALCAIRE             80        NON
# 6      PAV_M_P1_TPi_Gal                GALET             60        NON
# 7      PAV_M_P1_TPi_Gne               GNEISS             60        NON
# 8      IMM_M_P1_TPi_Gra              GRANITE             80        NON
# 9      IMM_M_P1_TPi_Gra              GRANITE             80        NON
# 10     PAV_M_P1_TPi_Gre                 GRES             70        NON
# 11     PAV_M_P1_TPi_Gre                 GRES             70        NON
# 12     IMM_M_P1_TPi_Meu             MEULIERE             80        NON
# 13     IMM_M_P1_TPi_Sch              SCHISTE             80        NON
# 14     IMM_M_P1_TPi_Vol           VOLCANIQUE             80        NON
# 15         IMM_M_P1_TPI               PIERRE             90        NON
# 16      PAV_M_P1_TBo-bo                 BOIS             50         IR
# 17      PAV_M_P1_TBr_br        BRIQUE PLEINE             60        NON
# 18     PAV_M_P1_TPi_Cal             CALCAIRE             80        NON
# 19     PAV_M_P1_TPi_Cal             CALCAIRE             80        NON
# 20     PAV_M_P1_TPi_Gal                GALET             60        NON
# 21     PAV_M_P1_TPi_Gne               GNEISS             60        NON
# 22     PAV_M_P1_TPi_Gra              GRANITE             60        NON
# 23     PAV_M_P1_TPi_Gra              GRANITE             60        NON
# 24     PAV_M_P1_TPi_Gre                 GRES             70        NON
# 25     PAV_M_P1_TPi_Gre                 GRES             70        NON
# 26     PAV_M_P1_TPi_Meu             MEULIERE             35        NON
# 27     PAV_M_P1_TPi_Sch              SCHISTE             40        NON
# 28     PAV_M_P1_TPi_Vol           VOLCANIQUE             80        NON
# 29     PAV_M_P1_TBr_Tcr          TERRE CUITE             50        NON
# 30       IMM_M_P2_TN_BB         BETON BANCHE             20        NON
# 31       IMM_M_P2_TN_PA             PARPAING             20        NON
# 32       IMM_M_P2_TN_PA             PARPAING             20        NON
# 33       IMM_M_P2_TN_BB         BETON BANCHE             20        NON
# 34       PAV_M_P2_TN_BC        BRIQUE CREUSE             20        NON
# 35       PAV_M_P2_TN_BC        BRIQUE CREUSE             20        NON
# 36       IMM_M_P3_TN_PA             PARPAING             20    ITI_AIR
# 37       IMM_M_P3_TN_PA             PARPAING             20    ITI_AIR
# 38       PAV_M_P3_TN_BC        BRIQUE CREUSE             20     ITI_LM
# 39       PAV_M_P3_TN_BC        BRIQUE CREUSE             20     ITI_LM
# 40  IMM_M_P4_TN_BB_isol         BETON BANCHE             40     ITE_LM
# 41  IMM_M_P4_TN_BB_isol         BETON BANCHE             40     ITE_LM
# 42       PAV_M_P4_TN_BC        BRIQUE CREUSE             20     ITI_LM
# 43       PAV_M_P4_TN_BC        BRIQUE CREUSE             20     ITI_LM
# 44       IMM_M_P5_TN_BB         BETON BANCHE             20     ITI_LM
# 45       IMM_M_P5_TN_BB         BETON BANCHE             20     ITI_LM
# 46       PAV_M_P5_TN_BC        BRIQUE CREUSE             20     ITI_LM
# 47       PAV_M_P5_TN_BC        BRIQUE CREUSE             20     ITI_LM
# 48       IMM_M_P6_TN_BB         BETON BANCHE             20     ITI_LM
# 49       IMM_M_P6_TN_BB         BETON BANCHE             20     ITI_LM
# 50   IMM_M_P6_TN_TER_MR  OSSATURE METALLIQUE              0         IR
# 51       PAV_M_P6_TN_PA             PARPAING             20     ITI_LM
# 52       PAV_M_P6_TN_PA             PARPAING             20     ITI_LM
# 53   IMM_M_P7_TN_REL_VB          VOILE BETON             50     ITE_LM
# 54   IMM_M_P7_TN_REL_VB          VOILE BETON             50     ITE_LM
# 55      PAV_M_P7_TN_PAR             PARPAING             20     ITE_LM
# 56      PAV_M_P7_TN_PAR             PARPAING             20     ITE_LM
#
#     EP_ISOLANT_M1 REVETEMENT_INT_M1  ...  renov_roof_Q3 renov_roof_max  \
# 0               0               NON  ...           0.30           1.07
# 1               0               NON  ...           0.30           1.11
# 2               0            ENDUIT  ...           0.32           1.11
# 3               0               NON  ...           0.32           1.18
# 4               0               NON  ...           0.32           1.18
# 5               0               NON  ...           0.32           1.18
# 6               0               NON  ...           0.32           1.18
# 7               0            ENDUIT  ...           0.32           1.18
# 8               0            ENDUIT  ...           0.32           1.18
# 9               0            ENDUIT  ...           0.32           1.18
# 10              0               NON  ...           0.32           1.18
# 11              0               NON  ...           0.32           1.18
# 12              0            ENDUIT  ...           0.32           1.18
# 13              0            ENDUIT  ...           0.32           1.18
# 14              0            ENDUIT  ...           0.32           1.18
# 15              0               NON  ...           0.25           1.11
# 16              0               NON  ...           0.30           1.11
# 17              0            ENDUIT  ...           0.33           1.18
# 18              0               NON  ...           0.30           1.16
# 19              0               NON  ...           0.30           1.16
# 20              0               NON  ...           0.30           1.16
# 21              0            ENDUIT  ...           0.30           1.16
# 22              0               NON  ...           0.30           1.16
# 23              0               NON  ...           0.30           1.16
# 24              0               NON  ...           0.30           1.16
# 25              0               NON  ...           0.30           1.16
# 26              0            ENDUIT  ...           0.30           1.16
# 27              0               NON  ...           0.30           1.16
# 28              0               NON  ...           0.30           1.16
# 29              0            ENDUIT  ...           0.29           1.11
# 30              0            ENDUIT  ...           0.50           2.30
# 31              0    CONTRE CLOISON  ...           0.43           1.19
# 32              0    CONTRE CLOISON  ...           0.43           1.19
# 33              0            ENDUIT  ...           0.43           2.30
# 34              0            ENDUIT  ...           0.34           1.19
# 35              0            ENDUIT  ...           0.34           1.19
# 36              1    CONTRE CLOISON  ...           0.30           0.39
# 37              1    CONTRE CLOISON  ...           0.30           0.39
# 38              6  PLAQUE DE PLATRE  ...           0.25           0.39
# 39              6  PLAQUE DE PLATRE  ...           0.25           0.39
# 40              6    CONTRE CLOISON  ...           0.24           0.26
# 41              6    CONTRE CLOISON  ...           0.24           0.26
# 42              5  PLAQUE DE PLATRE  ...           0.22           0.26
# 43              5  PLAQUE DE PLATRE  ...           0.22           0.26
# 44              6  PLAQUE DE PLATRE  ...           0.19           0.21
# 45              6  PLAQUE DE PLATRE  ...           0.19           0.21
# 46              6  PLAQUE DE PLATRE  ...           0.19           0.21
# 47              6  PLAQUE DE PLATRE  ...           0.19           0.21
# 48             10  PLAQUE DE PLATRE  ...           0.15           0.17
# 49             10  PLAQUE DE PLATRE  ...           0.15           0.17
# 50              0               NON  ...           0.20           0.26
# 51             10  PLAQUE DE PLATRE  ...           0.16           0.17
# 52             10  PLAQUE DE PLATRE  ...           0.16           0.17
# 53             16  PLAQUE DE PLATRE  ...           0.11           0.11
# 54             16  PLAQUE DE PLATRE  ...           0.11           0.11
# 55             16  PLAQUE DE PLATRE  ...           0.11           0.11
# 56             16  PLAQUE DE PLATRE  ...           0.11           0.11
#
#     EP_ISOL_M1_dist_med EP_ISOL_M1_dist_moy EP_ISOL_T1_dist_moy  \
# 0                   6.0                 2.0                 3.0
# 1                   5.0                -0.0                 2.0
# 2                   5.0                 1.0                 2.0
# 3                   3.0                 1.0                 2.0
# 4                   3.0                 1.0                 2.0
# 5                   3.0                 1.0                 2.0
# 6                   3.0                 2.0                 2.0
# 7                   3.0                 2.0                 2.0
# 8                   3.0                 1.0                 2.0
# 9                   3.0                 1.0                 2.0
# 10                  3.0                 1.0                 2.0
# 11                  3.0                 1.0                 2.0
# 12                  3.0                 1.0                 2.0
# 13                  3.0                 1.0                 2.0
# 14                  3.0                 1.0                 2.0
# 15                  7.0                 2.0                 4.0
# 16                  4.0                -0.0                 5.0
# 17                  4.0                 1.0                 4.0
# 18                  4.0                 1.0                 4.0
# 19                  4.0                 1.0                 4.0
# 20                  5.0                 2.0                 4.0
# 21                  5.0                 2.0                 4.0
# 22                  5.0                 2.0                 4.0
# 23                  5.0                 2.0                 4.0
# 24                  4.0                 2.0                 4.0
# 25                  4.0                 2.0                 4.0
# 26                  5.0                 2.0                 4.0
# 27                  5.0                 2.0                 4.0
# 28                  4.0                 1.0                 4.0
# 29                  6.0                 2.0                 5.0
# 30                  2.0                 2.0                 2.0
# 31                  1.0                 2.0                 0.0
# 32                  1.0                 2.0                 0.0
# 33                  3.0                 2.0                 3.0
# 34                  0.0                 1.0                 4.0
# 35                  0.0                 1.0                 4.0
# 36                  3.0                 3.0                 1.0
# 37                  3.0                 3.0                 1.0
# 38                  3.0                 3.0                 8.0
# 39                  3.0                 3.0                 8.0
# 40                  5.0                 4.0                 1.0
# 41                  5.0                 4.0                 1.0
# 42                  6.0                 5.0                11.0
# 43                  6.0                 5.0                11.0
# 44                  8.0                 6.0                 1.0
# 45                  8.0                 6.0                 1.0
# 46                  8.0                 7.0                12.0
# 47                  8.0                 7.0                12.0
# 48                 10.0                 7.0                 2.0
# 49                 10.0                 7.0                 2.0
# 50                  1.0                -2.0                 3.0
# 51                 10.0                 9.0                15.0
# 52                 10.0                 9.0                15.0
# 53                  9.0                 5.0                 3.0
# 54                  9.0                 5.0                 3.0
# 55                 10.0                 8.0                13.0
# 56                 10.0                 8.0                13.0
#
#     EP_ISOL_T1_dist_med EP_ISOL_M1_renov_med  EP_ISOL_M1_renov_moy  \
# 0                  14.0                  8.0                   6.0
# 1                  11.0                  6.0                   6.0
# 2                   9.0                  7.0                   5.0
# 3                   7.0                  7.0                   5.0
# 4                   7.0                  7.0                   5.0
# 5                   7.0                  7.0                   5.0
# 6                   7.0                  8.0                   6.0
# 7                   7.0                  8.0                   6.0
# 8                   7.0                  7.0                   5.0
# 9                   7.0                  7.0                   5.0
# 10                  7.0                  8.0                   6.0
# 11                  7.0                  8.0                   6.0
# 12                  7.0                  7.0                   5.0
# 13                  7.0                  7.0                   5.0
# 14                  7.0                  7.0                   5.0
# 15                 14.0                  9.0                   6.0
# 16                 15.0                  6.0                   5.0
# 17                 14.0                  7.0                   5.0
# 18                 14.0                  7.0                   5.0
# 19                 14.0                  7.0                   5.0
# 20                 14.0                  8.0                   6.0
# 21                 14.0                  8.0                   6.0
# 22                 14.0                  8.0                   6.0
# 23                 14.0                  8.0                   6.0
# 24                 14.0                  8.0                   6.0
# 25                 14.0                  8.0                   6.0
# 26                 14.0                  8.0                   6.0
# 27                 14.0                  8.0                   6.0
# 28                 14.0                  7.0                   5.0
# 29                 18.0                  9.0                   6.0
# 30                  8.0                  2.0                   2.0
# 31                  0.0                  1.0                   2.0
# 32                  0.0                  1.0                   2.0
# 33                 10.0                  3.0                   2.0
# 34                 11.0                  2.0                   2.0
# 35                 11.0                  2.0                   2.0
# 36                  3.0                  8.0                   8.0
# 37                  3.0                  8.0                   8.0
# 38                 14.0                  9.0                   9.0
# 39                 14.0                  9.0                   9.0
# 40                  7.0                  9.0                   9.0
# 41                  7.0                  9.0                   9.0
# 42                 14.0                  8.0                   8.0
# 43                 14.0                  8.0                   8.0
# 44                  9.0                 10.0                  10.0
# 45                  9.0                 10.0                  10.0
# 46                 16.0                  9.0                   9.0
# 47                 16.0                  9.0                   9.0
# 48                 13.0                 10.0                  11.0
# 49                 13.0                 10.0                  11.0
# 50                 15.0                  3.0                   4.0
# 51                 19.0                 12.0                  13.0
# 52                 19.0                 12.0                  13.0
# 53                 14.0                 19.0                  20.0
# 54                 14.0                 19.0                  20.0
# 55                 23.0                 20.0                  20.0
# 56                 23.0                 20.0                  20.0
#
#    EP_ISOL_T1_renov_moy  EP_ISOL_T1_renov_med
# 0                  13.0                  18.0
# 1                  13.0                  18.0
# 2                  12.0                  15.0
# 3                  12.0                  15.0
# 4                  12.0                  15.0
# 5                  12.0                  15.0
# 6                  12.0                  15.0
# 7                  12.0                  15.0
# 8                  12.0                  15.0
# 9                  12.0                  15.0
# 10                 12.0                  15.0
# 11                 12.0                  15.0
# 12                 12.0                  15.0
# 13                 12.0                  15.0
# 14                 12.0                  15.0
# 15                 15.0                  19.0
# 16                 14.0                  18.0
# 17                 13.0                  18.0
# 18                 13.0                  18.0
# 19                 13.0                  18.0
# 20                 13.0                  18.0
# 21                 13.0                  18.0
# 22                 13.0                  18.0
# 23                 13.0                  18.0
# 24                 13.0                  18.0
# 25                 13.0                  18.0
# 26                 13.0                  18.0
# 27                 13.0                  18.0
# 28                 13.0                  18.0
# 29                 14.0                  19.0
# 30                  6.0                  14.0
# 31                  9.0                  13.0
# 32                  9.0                  13.0
# 33                  8.0                  15.0
# 34                 11.0                  14.0
# 35                 11.0                  14.0
# 36                 15.0                  16.0
# 37                 15.0                  16.0
# 38                 17.0                  19.0
# 39                 17.0                  19.0
# 40                 18.0                  19.0
# 41                 18.0                  19.0
# 42                 19.0                  19.0
# 43                 19.0                  19.0
# 44                 21.0                  19.0
# 45                 21.0                  19.0
# 46                 22.0                  20.0
# 47                 22.0                  20.0
# 48                 27.0                  26.0
# 49                 27.0                  26.0
# 50                 19.0                  19.0
# 51                 26.0                  26.0
# 52                 26.0                  26.0
# 53                 38.0                  38.0
# 54                 38.0                  38.0
# 55                 38.0                  38.0
# 56                 38.0                  38.0
#
# [57 rows x 125 columns]

# %%
df_anlz_complete.to_excel("analyzed_groups_stats_U_e.xlsx")

# %% [markdown]
# ### old

# %%
renov_perc = {}
for csv in bounds.index:   
    
    # U boundaries
    uw_min  = bounds.loc[csv, "Uw_min"]
    uw_max  = bounds.loc[csv, "Uw_max"]
    uph_min  = bounds.loc[csv, "Uph_min"]
    uph_max  = bounds.loc[csv, "Uph_max"]
    u_bounds = (uw_min, uw_max, uph_min, uph_max)
    
    # csv
    path = source_folder / csv
    root_name = "-".join(path.stem.split("-")[2:-1]) 
    print("\n", root_name)
    print(csv)
    dpe = pd.read_csv(path)

    # percentage
    # wall perc
    below_bound_wall = len(dpe[dpe["adedpe202006_logtype_mur_u_ext"] < uw_min]) / len(dpe)
    within_bound_wall = len(dpe[(dpe["adedpe202006_logtype_mur_u_ext"] >= uw_min) & 
                                (dpe["adedpe202006_logtype_mur_u_ext"] <= uw_max)] ) / len(dpe)
    above_bound_wall = len(dpe[dpe["adedpe202006_logtype_mur_u_ext"] > uw_max]) / len(dpe)
    # roof perc
    below_bound_roof = len(dpe[dpe["adedpe202006_logtype_ph_u"] < uph_min]) / len(dpe)
    within_bound_roof = len(dpe[(dpe["adedpe202006_logtype_ph_u"] >= uph_min) & 
                                    (dpe["adedpe202006_logtype_ph_u"] <= uph_max)] ) / len(dpe)
    above_bound_roof = len(dpe[dpe["adedpe202006_logtype_ph_u"] > uph_max]) / len(dpe)
    
    renov_perc[csv] = { "below_bound_wall" : below_bound_wall,
                        "within_bound_wall" : within_bound_wall,
                        "above_bound_wall" : above_bound_wall,
                        "below_bound_roof" : below_bound_roof,
                        "within_bound_roof" : within_bound_roof,
                        "above_bound_roof" : above_bound_roof,
                        }
    perc_wall = (below_bound_wall, within_bound_wall, above_bound_wall)
    perc_roof = (below_bound_roof, within_bound_roof, above_bound_roof)
       
    # plot
    figure, df_roof, df_wall = plot_dens_wall_roof_side(dpe, u_bounds, root_name, perc_wall, perc_roof)
    save_fig_name = "Dens_" + root_name + ".png"
    figure.savefig(save_fig_folder / "side_by_side" / save_fig_name)

# %%
for csv,bound in renov_perc.items():
    print("\n",csv)
    
    for k,v in bound.items():
        print(k,v)
        
    print(sum(bound.values()))

# %%
for csv in bounds.index[:2]:
    uw_min  = bounds.loc[csv, "Uw_min"]
    uw_max  = bounds.loc[csv, "Uw_max"]
    uph_min  = bounds.loc[csv, "Uph_min"]
    uph_max  = bounds.loc[csv, "Uph_max"]
    u_bounds = (uw_min, uw_max, uph_min, uph_max)
    
    path = source_folder / csv
    root_name = "-".join(path.stem.split("-")[2:-1]) 
    print("\n", root_name)
    print(csv)
    dpe = pd.read_csv(path)

    figure, df_roof, df_wall = plot_dens_wall_roof_side(dpe, u_bounds, root_name)
    save_fig_name = "Dens_" + root_name + ".png"
    figure.savefig(save_fig_folder / "side_by_side" / save_fig_name)
# Out:
#  P1-I-HABITAT-FRANCE_BOIS_TUILE
# dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUILE-uniq.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3012/254993845.py in <module>
#      12     dpe = pd.read_csv(path)
#      13
# ---> 14     figure, df_roof, df_wall = plot_dens_wall_roof_side(dpe, u_bounds, root_name)
#      15     save_fig_name = "Dens_" + root_name + ".png"
#      16     figure.savefig(save_fig_folder / "side_by_side" / save_fig_name)
#
# TypeError: plot_dens_wall_roof_side() missing 2 required positional arguments: 'perc_wall' and 'perc_roof'

# %% [markdown]
# ### checking one case with orange

# %%
[arch for arch in dan.archetype.unique() if "P2-I-COMMERCE-FRANCE" in arch]

# %%
dan[dan.archetype == "P2-I-COMMERCE-FRANCE"]
# lim max = 2.9 > highest case
# red goes in the opposite direction
# probabily boundaries of Danube need to be revised

# %% [markdown]
# ### checking one case with high percentage in the red

# %%
csv = r"dpe_all3-len_11838-P4-I-HABITAT-FRANCE-toit.csv"
path = source_folder / csv

p4_test = pd.read_csv(path, index_col=0)

# %%
dan_p4_test = dan[dan.fichier == csv]
dan_p4_test

# %%
[var for var in  list(p4_test.columns) if "cons" in var]

# %%
sorted(p4_test.cerffo2020_annee_construction.unique())
# the attribution of construction dates is correct

# %% [markdown]
# - **La limite supérieure de U est majoritairement issue de l'hypothèse oùu le mur est inconnue, celle qui ne dépend pas des dispositifs Danube, mais uniquement des dates de construcions des bâtiments présentes pour un arquétype associé à une période**
#
# - **Dans les annés proches de limites de définition des périodes, il peut avoir une différence entre la catégorie d'anné de la méthode 3CL et de Danube. Ce qui peut avoir une variation legere des limites pour les hypothèses où de valeurs forfaitaires sont utilisés.**
#
# - **Est-ce qu'on doit considérer les dpe de ces bâtiments qui ont une performance au dessus de celle prévu par l'hypothèse inconnue comme des dpe non fiables ?**
#
# - **si oui, est-ce qu'on écarte ces données et défini le omega seulement les dpe qui sont au dessous de la limite supérieur ? Je pense que non, car cela irait augmenter encore plus le percentage des bâtiments rénovés.**

# %%
mat_vars = [var for var in  list(p4_test.columns) if "mat" in var]

# %%
for mat_var in mat_vars:
    print(mat_var)
#     print(p4_test[mat_var].unique(),"\n")
    print(p4_test[mat_var].value_counts() / len(p4_test) * 100,"\n")

# %% [markdown]
# ###  fin
