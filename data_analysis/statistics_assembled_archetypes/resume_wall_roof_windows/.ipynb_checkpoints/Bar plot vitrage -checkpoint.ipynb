# %%
from pathlib import Path
from os import listdir
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
save_fig_path = Path

# %%
path_vit = r"resume_vitrage.xlsx"
df = pd.read_excel(path_vit, index_col=0)
df.head(2)
# Out:
#                                               fichier  \
# 0   dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUI...
# 19  dpe_all3-len_52731-P1-P-HABITAT-FRANCE_PIERRE-...
#
#                                            archétypes  simp_vit_3CL  \
# 0                  ['P1-I-HABITAT-FRANCE_BOIS_TUILE']          11.1
# 19  ['P1-P-HABITAT-FRANCE_PIERRE_CALCAIRE_TUILE', ...          14.9
#
#     doub_vit_3CL  trip_vit_3CL    main_vit_3CL main_vit_Danube  Danube_OK  \
# 0           88.2           0.7  double vitrage  simple vitrage      False
# 19          84.5           0.4  double vitrage  simple vitrage      False
#
#     somme per
# 0   100.0  P1
# 19   99.8  P1

# %% [markdown]
# ### Plot all

# %%
def take_root(row):
    return "-".join(row['fichier'].split("-")[2:-1])
    
df["groupe"] = df.apply(lambda row: take_root(row), axis=1)
df.head(2)
# Out:
#                                               fichier  \
# 0   dpe_all3-len_1010-P1-I-HABITAT-FRANCE_BOIS_TUI...
# 19  dpe_all3-len_52731-P1-P-HABITAT-FRANCE_PIERRE-...
#
#                                            archétypes  simp_vit_3CL  \
# 0                  ['P1-I-HABITAT-FRANCE_BOIS_TUILE']          11.1
# 19  ['P1-P-HABITAT-FRANCE_PIERRE_CALCAIRE_TUILE', ...          14.9
#
#     doub_vit_3CL  trip_vit_3CL    main_vit_3CL main_vit_Danube  Danube_OK  \
# 0           88.2           0.7  double vitrage  simple vitrage      False
# 19          84.5           0.4  double vitrage  simple vitrage      False
#
#     somme per                          groupe
# 0   100.0  P1  P1-I-HABITAT-FRANCE_BOIS_TUILE
# 19   99.8  P1      P1-P-HABITAT-FRANCE_PIERRE

# %%
df.sort_values("groupe", ascending=False, inplace=True)
df.head(2)
# Out:
#                                             fichier  \
# 17  dpe_all3-len_48162-P7-P-HABITAT-FRANCE-toit.csv
# 21   dpe_all3-len_9137-P7-I-HABITAT-FRANCE-toit.csv
#
#                                            archétypes  simp_vit_3CL  \
# 17  ['P7-P-HABITAT-FRANCE_ARDOISE', 'P7-P-HABITAT-...           3.9
# 21  ['P7-I-HABITAT-FRANCE_ARDOISE', 'P7-I-HABITAT-...           5.9
#
#     doub_vit_3CL  trip_vit_3CL    main_vit_3CL  \
# 17          94.8           1.3  double vitrage
# 21          92.8           1.2  double vitrage
#
#                          main_vit_Danube  Danube_OK  somme per  \
# 17  double vitrage a isolation renforcee       True  100.0  P7
# 21  double vitrage a isolation renforcee       True   99.9  P7
#
#                  groupe
# 17  P7-P-HABITAT-FRANCE
# 21  P7-I-HABITAT-FRANCE

# %%
# Plot all
cols = ["groupe", "simp_vit_3CL", "doub_vit_3CL", "trip_vit_3CL"]

fig, ax = plt.subplots(figsize=(10,10))
df[cols].plot(x='groupe', kind='barh', stacked=True, ax=ax, colormap='rainbow_r')

plt.title("Type de vitrage",fontweight="bold")
plt.ylabel("Groupe")
plt.xlabel("Pourcentage (%)")
ax.legend(["simple", "double", "triple"],loc=9)

fig.savefig("Type_de_vitrage.png",bbox_inches='tight')

# %% [markdown]
# ### Separate the groupes habitat and others

# %%
df_hab = df[df['fichier'].str.contains('HABITAT')]
df_ter_com = df[~df['fichier'].str.contains('HABITAT')]

# %%
df_ter_com
# Out:
#                                             fichier  \
# 16  dpe_all3-len_364-P6-I-TERTIAIRE-FRANCE-nati.csv
# 13  dpe_all3-len_320-P2-I-TERTIAIRE-FRANCE-nati.csv
# 20   dpe_all3-len_634-P2-I-COMMERCE-FRANCE-nati.csv
# 22   dpe_all3-len_916-P1-I-COMMERCE-FRANCE-nati.csv
#
#                    archétypes  simp_vit_3CL  doub_vit_3CL  trip_vit_3CL  \
# 16  ['P6-I-TERTIAIRE-FRANCE']           4.9          94.8           0.3
# 13  ['P2-I-TERTIAIRE-FRANCE']          15.9          83.4           0.6
# 20   ['P2-I-COMMERCE-FRANCE']          18.0          81.9           0.2
# 22   ['P1-I-COMMERCE-FRANCE']           9.4          90.4           0.2
#
#       main_vit_3CL main_vit_Danube  Danube_OK  somme per  \
# 16  double vitrage  double vitrage       True  100.0  P6
# 13  double vitrage  simple vitrage      False   99.9  P2
# 20  double vitrage  simple vitrage      False  100.1  P2
# 22  double vitrage  simple vitrage      False  100.0  P1
#
#                    groupe
# 16  P6-I-TERTIAIRE-FRANCE
# 13  P2-I-TERTIAIRE-FRANCE
# 20   P2-I-COMMERCE-FRANCE
# 22   P1-I-COMMERCE-FRANCE

# %%
# Plot commerce & tertiare
cols = ["groupe", "simp_vit_3CL", "doub_vit_3CL", "trip_vit_3CL"]

fig_com, ax = plt.subplots(figsize=(10,2))
df_ter_com[cols].plot(x='groupe', kind='barh', stacked=True, ax=ax, colormap='rainbow_r',)

plt.title("Type de vitrage : Commmerce & Tertiare",fontweight="bold")
plt.ylabel("Groupe")
plt.xlabel("Pourcentage (%)")
ax.legend(["simple", "double", "triple"],loc=9)

fig_com.savefig("Type_de_vitrage_com_tert.png",bbox_inches='tight')

# %%
# Plot habitat
cols = ["groupe", "simp_vit_3CL", "doub_vit_3CL", "trip_vit_3CL"]

fig_hab, ax = plt.subplots(figsize=(10,10))
df_hab[cols].plot(x='groupe', kind='barh', stacked=True, ax=ax,
             colormap='rainbow_r',)
plt.title("Type de vitrage : Habitat",fontweight="bold")
plt.ylabel("Groupe")
plt.xlabel("Pourcentage (%)")
ax.legend(["simple", "double", "triple"],loc=9)
fig_hab.savefig("Type_de_vitrage_habitat.png",bbox_inches='tight')
