# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"DISPOSITIFS_MUR-export.csv")
df
# Out:
#              DISPOSITIF              PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 0    BA_M_P2_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 1    BA_M_P3_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 2         BA_M_P4_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 3         BA_M_P5_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 4         BA_M_P6_TN_PS  OSSATURE METALLIQUE           0      IR           0
# ..                  ...                  ...         ...     ...         ...
# 145         SER_M_P3_TN  OSSATURE METALLIQUE           0     NON           0
# 146         SER_M_P4_TN  OSSATURE METALLIQUE           0     NON           0
# 147         SER_M_P5_TN  OSSATURE METALLIQUE           0     NON           0
# 148         SER_M_P6_TN  OSSATURE METALLIQUE           0     NON           0
# 149         SER_M_P7_TN  OSSATURE METALLIQUE           0     NON           0
#
#     REVETEMENT_INT  EP_RI    REVETEMENT_EXT  EP_RE
# 0              NON    0.0  PANNEAU SANDWICH      5
# 1              NON    0.0  PANNEAU SANDWICH      5
# 2              NON    0.0  PANNEAU SANDWICH      6
# 3              NON    0.0  PANNEAU SANDWICH     10
# 4              NON    0.0  PANNEAU SANDWICH     12
# ..             ...    ...               ...    ...
# 145            NON    0.0    SIMPLE VITRAGE      2
# 146            NON    0.0    SIMPLE VITRAGE      2
# 147            NON    0.0    DOUBLE VITRAGE      3
# 148            NON    0.0    DOUBLE VITRAGE      3
# 149            NON    0.0    DOUBLE VITRAGE      3
#
# [150 rows x 9 columns]

# %%
file_loc = r"C:\Users\ldecarva\Documents\Data\Danube\BDD\Ancienne version\Fichiers-BDD-architecturale-MApUCE-v1.15.2-archives\_240616_BddMAPUCE_MAP_V15.2-export.csv"
danube = pd.read_csv(file_loc, sep=";", index_col="NUMERO_TYPOLOGIE")

# order by inputs in the first 4 columns and then the other variables in alphabetic order
col_ord = ['USAGE','NOM_TYPOLOGIE','PERIODE','TERRITOIRE',
           
       'DISPOSITIF',  'PORTEUR', 'ISOLANT', 'REVETEMENT_EXT','REVETEMENT_INT',
                       'EP_PORTEUR', 'EP_ISOLANT', 'EP_RE','EP_RI',
              
        'DISPOSITIF_MUR_OPTION1', 'DISPOSITIF_MUR_OPTION2', 'DISPOSITIF_MUR_OPTION3', 
        'DISPOSITIF_TOIT_OPTION2', 'DISPOSTIIF_TOIT_ OPTION1',
           
        'PORTEUR1', 'PORTEUR2', 'PORTEUR4', 
        'REVETEMENT_EXT1', 'REVETEMENT_EXT2', 'REVETEMENT_EXT4',
        'REVETEMENT_INT1', 'REVETEMENT_INT2', 'REVETEMENT_INT4',  
        'DISPOSITIF1', 'DISPOSITIF2',  'DISPOSITIF4',
        'EP_ISOLANT1', 'EP_ISOLANT2', 'EP_ISOLANT4',
        'EP_PORTEUR1', 'EP_PORTEUR2','EP_PORTEUR4',
        'EP_RE1', 'EP_RE2', 'EP_RE4',
        'EP_RI1', 'EP_RI2','EP_RI4',  
        'ISOLANT1', 'ISOLANT2', 'ISOLANT4', 
           
        'TERRITOIRE1','TERRITOIRE_DESC', 'TERRITOIRE_SHORT_ID', 'NUMERO_PERIODE', 'DATES', 'DATE_DEBUT', 'DATE_FIN',
           
        'TYPE_VITRAGE', 'POURCENTAGE_VITRAGE','PROTECTIONS_SOLAIRES',
        'VENTILATION','PERMEABILITE',
        'COMPACITE', 'COUVERTURE_ROUTE', 

           
        'PLANCHER_INTERMEDIAIRE',  'EP_PLANCHER_RDC', 'EP_PLANCHER_INTER','ID_PLANCHER','PLANCHER_RDC', 'PLANCHER', 

           
        'DISPOSITIF3','PORTEUR3', 'ISOLANT3', 'REVETEMENT_EXT3','REVETEMENT_INT3',
                      'EP_PORTEUR3', 'EP_ISOLANT3', 'EP_RE3',   'EP_RI3', 
          ]

danube = danube[col_ord].sort_values(['PERIODE', 'NOM_TYPOLOGIE',"USAGE","TERRITOIRE"])
danube.head()
# Out:
#                                 USAGE NOM_TYPOLOGIE PERIODE  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBR_TF    BATIMENT AGRICOLE            BA      P1
# AGR_BA_P1_TBO_ARD   BATIMENT AGRICOLE            BA      P1
# AGR_BA_P1_TBO_TUI   BATIMENT AGRICOLE            BA      P1
# AGR_BA_P1_TBR_TUI   BATIMENT AGRICOLE            BA      P1
# AGR_BA_P1_TCAL_ARD  BATIMENT AGRICOLE            BA      P1
#
#                                         TERRITOIRE        DISPOSITIF  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBR_TF                            FRANCE   PAV_M_P1_TBr_br
# AGR_BA_P1_TBO_ARD              FRANCE_BOIS_ARDOISE   PAV_M_P1_TBo-bo
# AGR_BA_P1_TBO_TUI                FRANCE_BOIS_TUILE   PAV_M_P1_TBo-bo
# AGR_BA_P1_TBR_TUI              FRANCE_BRIQUE_TUILE   PAV_M_P1_TBr_br
# AGR_BA_P1_TCAL_ARD  FRANCE_PIERRE_CALCAIRE_ARDOISE  PAV_M_P1_TPi_Cal
#
#                           PORTEUR ISOLANT REVETEMENT_EXT REVETEMENT_INT  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBR_TF    BRIQUE PLEINE     NON         ENDUIT         ENDUIT
# AGR_BA_P1_TBO_ARD            BOIS      IR            NON            NON
# AGR_BA_P1_TBO_TUI            BOIS      IR            NON            NON
# AGR_BA_P1_TBR_TUI   BRIQUE PLEINE     NON         ENDUIT         ENDUIT
# AGR_BA_P1_TCAL_ARD       CALCAIRE     NON         ENDUIT            NON
#
#                     EP_PORTEUR  ...           PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE                ...
# AGR_BA_P1_TBR_TF            60  ...  TERRE BATTUE1NON0  HAB_T_P1_TBR_TU
# AGR_BA_P1_TBO_ARD           50  ...  TERRE BATTUE1NON0  HAB_T_P1_TPI_AR
# AGR_BA_P1_TBO_TUI           50  ...  TERRE BATTUE1NON0  HAB_T_P1_TBR_TM
# AGR_BA_P1_TBR_TUI           60  ...  TERRE BATTUE1NON0  HAB_T_P1_TBR_TU
# AGR_BA_P1_TCAL_ARD          80  ...  TERRE BATTUE1NON0  HAB_T_P1_TPI_AR
#
#                           PORTEUR3 ISOLANT3  REVETEMENT_EXT3 REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBR_TF    STRUCTURE BOIS      NON            TUILE             NON
# AGR_BA_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# AGR_BA_P1_TBO_TUI   STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# AGR_BA_P1_TBR_TUI   STRUCTURE BOIS      NON            TUILE             NON
# AGR_BA_P1_TCAL_ARD  STRUCTURE BOIS      NON          ARDOISE             NON
#
#                    EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBR_TF             0           0    2.0    0.0
# AGR_BA_P1_TBO_ARD            0           0    2.0    0.0
# AGR_BA_P1_TBO_TUI            0           0    2.0    0.0
# AGR_BA_P1_TBR_TUI            0           0    2.0    0.0
# AGR_BA_P1_TCAL_ARD           0           0    2.0    0.0
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Period

# %%
df["period"] = df.DISPOSITIF.str.split("_", expand=True)[2]

# %%
dfsort = df.sort_values("period")
x = dfsort.EP_ISOLANT
y = dfsort.period
plt.scatter(x,y, alpha=0.05)

# %% [markdown]
# #### Cases of period not matching

# %%
for disp_t in danube["DISPOSITIF_MUR_OPTION1"].unique():
    print("\n",disp_t)
    per = disp_t.split("_")[2]
    
    archs_disp_toit = danube[danube["DISPOSITIF_MUR_OPTION1"]==disp_t][["TERRITOIRE", 
                                                        "PERIODE",
                                                        "PORTEUR3",
                                                        "EP_PORTEUR3",
                                                        "ISOLANT3",
                                                        "EP_ISOLANT3",
                                                        "REVETEMENT_EXT3",
                                                        "EP_RE3",
                                                        "REVETEMENT_INT3",
                                                        "EP_RI3",]]
    
    not_match = archs_disp_toit[~archs_disp_toit.PERIODE.str.startswith(per)]
    
    if len(not_match) > 0 :
        print(per)
        display(not_match)
# Out:
#  PAV_M_P1_TBr_br
#
#  PAV_M_P1_TBo-bo
#
#  PAV_M_P1_TPi_Cal
#
#  PAV_M_P1_TPi_Gal
#
#  PAV_M_P1_TPi_Gne
#
#  PAV_M_P1_TPi_Gra
#
#  PAV_M_P1_TPi_Gre
#
#  PAV_M_P1_TPi_Meu
#
#  PAV_M_P1_TPi_Sch
#
#  PAV_M_P1_TPi_Vol
#
#  PAV_M_P1_TPB_pi
#
#  IMM_M_P1_TPI
#
#  SER_M_P1_TN
#
#  IMM_M_P1_TPi_Vol
#
#  IMM_M_P1_TPi_Sch
#
#  IMM_M_P1_TBr_br
#
#  IMM_M_P1_TPi_Gra
#
#  IMM_M_P1_TPi_Meu
#
#  PAV_M_P1_TPI
#
#  BA_M_P2_TN_IND_TOL
# P2
#                  TERRITOIRE PERIODE         PORTEUR3  EP_PORTEUR3 ISOLANT3  \
# NUMERO_TYPOLOGIE
# BA_LNC_P7_TF         FRANCE      P7  STRUCTURE METAL            0      NON
#
#                   EP_ISOLANT3 REVETEMENT_EXT3  EP_RE3 REVETEMENT_INT3  EP_RI3
# NUMERO_TYPOLOGIE
# BA_LNC_P7_TF                0            TOLE     0.8             NON     0.0
#  SER_M_P2_TN
#
#  IMM_M_P2_TN_SCO_PRE
#
#  IMM_M_P2_TN_BB
#
#  IMM_M_P2_TN_PA
#
#  BGH_M_P4_TN_HAB_BE_BE
# P4
#                  TERRITOIRE PERIODE     PORTEUR3  EP_PORTEUR3 ISOLANT3  \
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF        FRANCE      P2  DALLE BETON           20      NON
# HAB_IGH_P3_TF        FRANCE      P3  DALLE BETON           20      NON
#
#                   EP_ISOLANT3 REVETEMENT_EXT3  EP_RE3 REVETEMENT_INT3  EP_RI3
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF               0         GRAVIER     5.0             NON     0.0
# HAB_IGH_P3_TF               0         GRAVIER     5.0             NON     0.0
#  PAV_M_P2_TN_BC
#
#  PAV_M_P2_TBR
#
#  LNC_M_P2_TN_BC
# P2
#                  TERRITOIRE PERIODE        PORTEUR3  EP_PORTEUR3 ISOLANT3  \
# NUMERO_TYPOLOGIE
# LNC_P_P3_TF          FRANCE      P3  STRUCTURE BOIS            0      NON
# LNC_P_P4_TF          FRANCE      P4  STRUCTURE BOIS            0      NON
# LNC_P_P5_TF          FRANCE      P5  STRUCTURE BOIS            0      NON
# LNC_P_P6_TF          FRANCE      P6  STRUCTURE BOIS            0      NON
# LNC_P_P7_TF          FRANCE      P7  STRUCTURE BOIS            0      NON
#
#                   EP_ISOLANT3 REVETEMENT_EXT3  EP_RE3 REVETEMENT_INT3  EP_RI3
# NUMERO_TYPOLOGIE
# LNC_P_P3_TF                 0           TUILE     2.0             NON     0.0
# LNC_P_P4_TF                 0           TUILE     2.0             NON     0.0
# LNC_P_P5_TF                 0           TUILE     2.0             NON     0.0
# LNC_P_P6_TF                 0           TUILE     2.0             NON     0.0
# LNC_P_P7_TF                 0           TUILE     2.0             NON     0.0
#  BA_M_P3_TN_IND_TOL
#
#  SER_M_P3_TN
#
#  IMM_M_P3_TN_SCO_PRE
#
#  IMM_M_P4_TN_BB
# P4
#                  TERRITOIRE PERIODE     PORTEUR3  EP_PORTEUR3 ISOLANT3  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF          FRANCE      P3  DALLE BETON           20      NON
#
#                   EP_ISOLANT3 REVETEMENT_EXT3  EP_RE3 REVETEMENT_INT3  EP_RI3
# NUMERO_TYPOLOGIE
# REL_I_P3_TF                 0         GRAVIER     5.0             NON     0.0
#  IMM_M_P3_TN_COM_BE
#
#  IMM_M_P3_TN_PA
#
#  IMM_M_P3_TN_REL_BA
#
#  PAV_M_P3_TN_BC
#
#  BA_M_P4_TN_PS
#
#  SER_M_P4_TN
#
#  IMM_M_P4_TN_SCO_PRE
#
#  BGH_M_P4_TN_TER_MR
#
#  PAV_M_P4_TN_BC
#
#  BA_M_P5_TN_PS
#
#  SER_M_P5_TN
#
#  IMM_M_P5_TN_SCO_PRE
#
#  IMM_M_P5_TN_BB
#
#  BGH_M_P5_TN_HAB_BE_BE
#
#  BGH_M_P5_TN_TER_MR
#
#  PAV_M_P5_TN_BC
#
#  BA_M_P6_TN_PS
#
#  SER_M_P6_TN
#
#  IMM_M_P6_TN_BB
#
#  IMM_M_P6_TN_TER_MR
#
#  BGH_M_P6_TN_TER_MR
#
#  PAV_M_P6_TN_PA
#
#  PAV_M_P6_TN_BR
#
#  BA_M_P7_TN_PS
#
#  SER_M_P7_TN
#
#  IMM_M_P7_TN_TER_BE
#
#  IMM_M_P7_TN_REL_VB
#
#  IMM_M_P7_TN_TER_MR
#
#  BGH_M_P7_TN_HAB_MR
#
#  BGH_M_P7_TN_TER_MR
#
#  PAV_M_P7_TN_PAR

# %% [markdown]
# **The following disp_mur are not in accordance with the period of the archetype**
# - BA_M_P2_TN_IND_TOL
#     - BA_LNC_P7_TF
#
# - BGH_M_P4_TN_HAB_BE_BE
#     - HAB_IGH_P2_TF
#     - HAB_IGH_P3_TF
#
# - LNC_M_P2_TN_BC
#     - LNC_P_P3_TF
#     - LNC_P_P4_TF
#     - LNC_P_P5_TF
#     - LNC_P_P6_TF
#
# - IMM_M_P4_TN_BB
#     - REL_I_P3_TF
#
# The cases of LNC can be neglected, but the others should be investigated.

# %% [markdown]
# ##### Cases HAB

# %%
df[df.DISPOSITIF == "BGH_M_P4_TN_HAB_BE_BE"]
# Out:
#               DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 7  BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM           5
#
#      REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 7  PLAQUE DE PLATRE    1.3  PANNEAU BETON     15

# %%
df[df.DISPOSITIF.str.startswith("BGH")]
# The equivalent dispositif for period P2 exists, but without insulation
# There is not an equivalent for P3
# Should I create one? yes equal to P4, but changing the name
# Out:
#                DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 6   BGH_M_P2_TN_HAB_BE_BE  OSSATURE BETON           0     NON           0
# 7   BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM           5
# 8      BGH_M_P4_TN_TER_MR  OSSATURE BETON           0      IR           0
# 9   BGH_M_P5_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM          10
# 10     BGH_M_P5_TN_TER_MR  OSSATURE BETON           0      IR           0
# 11     BGH_M_P6_TN_HAB_MR  OSSATURE BETON           0      IR           0
# 12     BGH_M_P6_TN_TER_MR  OSSATURE BETON           0      IR           0
# 13     BGH_M_P7_TN_HAB_MR  OSSATURE BETON           0      IR           0
# 14     BGH_M_P7_TN_TER_MR  OSSATURE BETON           0      IR           0
#
#       REVETEMENT_INT  EP_RI     REVETEMENT_EXT  EP_RE
# 6   PLAQUE DE PLATRE    1.3      PANNEAU BETON     15
# 7   PLAQUE DE PLATRE    1.3      PANNEAU BETON     15
# 8                NON    0.0   MUR RIDEAU VERRE     10
# 9   PLAQUE DE PLATRE    1.3      PANNEAU BETON     15
# 10               NON    0.0  MUR RIDEAU VERRE      10
# 11               NON    0.0   MUR RIDEAU VERRE     10
# 12               NON    0.0   MUR RIDEAU VERRE     10
# 13               NON    0.0   MUR RIDEAU VERRE     10
# 14               NON    0.0   MUR RIDEAU VERRE     10

# %%
danube[danube.DISPOSITIF == "BGH_M_P4_TN_HAB_BE_BE"]
# Out:
#                     USAGE NOM_TYPOLOGIE PERIODE TERRITOIRE  \
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF     HABITAT           IGH      P2     FRANCE
# HAB_IGH_P3_TF     HABITAT           IGH      P3     FRANCE
# HAB_IGH_P4_TF     HABITAT           IGH      P4     FRANCE
#
#                              DISPOSITIF         PORTEUR ISOLANT  \
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF     BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON  ITI_LM
# HAB_IGH_P3_TF     BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON  ITI_LM
# HAB_IGH_P4_TF     BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON  ITI_LM
#
#                  REVETEMENT_EXT    REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                                               ...
# HAB_IGH_P2_TF     PANNEAU BETON  PLAQUE DE PLATRE           0  ...
# HAB_IGH_P3_TF     PANNEAU BETON  PLAQUE DE PLATRE           0  ...
# HAB_IGH_P4_TF     PANNEAU BETON  PLAQUE DE PLATRE           0  ...
#
#                                              PLANCHER     DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF     DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P2_TN_GR
# HAB_IGH_P3_TF     DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P3_TN_GR
# HAB_IGH_P4_TF     DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P4_TN_GR
#
#                      PORTEUR3 ISOLANT3 REVETEMENT_EXT3   REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF     DALLE BETON      NON         GRAVIER               NON
# HAB_IGH_P3_TF     DALLE BETON      NON         GRAVIER               NON
# HAB_IGH_P4_TF     DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
#
#                  EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# HAB_IGH_P2_TF             20           0    5.0    0.0
# HAB_IGH_P3_TF             20           0    5.0    0.0
# HAB_IGH_P4_TF             20          12    5.0    1.3
#
# [3 rows x 79 columns]

# %%
# The dispositif BGH_M_P2_TN_HAB_BE_BE is not used anywhere
# It is because the Danube version was not the last one. actually the problem for P2 is already solved.
# However, the problem of P3 is not solved yet. We should create BGH_M_P3_TN_HAB_BE_BE replicating the one of P4

display(danube[danube.DISPOSITIF == "BGH_M_P2_TN_HAB_BE_BE"])
display(danube[danube.DISPOSITIF1 == "BGH_M_P2_TN_HAB_BE_BE"])
danube[danube.DISPOSITIF2 == "BGH_M_P2_TN_HAB_BE_BE"]
# Out:
# Empty DataFrame
# Columns: [USAGE, NOM_TYPOLOGIE, PERIODE, TERRITOIRE, DISPOSITIF, PORTEUR, ISOLANT, REVETEMENT_EXT, REVETEMENT_INT, EP_PORTEUR, EP_ISOLANT, EP_RE, EP_RI, DISPOSITIF_MUR_OPTION1, DISPOSITIF_MUR_OPTION2, DISPOSITIF_MUR_OPTION3, DISPOSITIF_TOIT_OPTION2, DISPOSTIIF_TOIT_ OPTION1, PORTEUR1, PORTEUR2, PORTEUR4, REVETEMENT_EXT1, REVETEMENT_EXT2, REVETEMENT_EXT4, REVETEMENT_INT1, REVETEMENT_INT2, REVETEMENT_INT4, DISPOSITIF1, DISPOSITIF2, DISPOSITIF4, EP_ISOLANT1, EP_ISOLANT2, EP_ISOLANT4, EP_PORTEUR1, EP_PORTEUR2, EP_PORTEUR4, EP_RE1, EP_RE2, EP_RE4, EP_RI1, EP_RI2, EP_RI4, ISOLANT1, ISOLANT2, ISOLANT4, TERRITOIRE1, TERRITOIRE_DESC, TERRITOIRE_SHORT_ID, NUMERO_PERIODE, DATES, DATE_DEBUT, DATE_FIN, TYPE_VITRAGE, POURCENTAGE_VITRAGE, PROTECTIONS_SOLAIRES, VENTILATION, PERMEABILITE, COMPACITE, COUVERTURE_ROUTE, PLANCHER_INTERMEDIAIRE, EP_PLANCHER_RDC, EP_PLANCHER_INTER, ID_PLANCHER, PLANCHER_RDC, PLANCHER, DISPOSITIF3, PORTEUR3, ISOLANT3, REVETEMENT_EXT3, REVETEMENT_INT3, EP_PORTEUR3, EP_ISOLANT3, EP_RE3, EP_RI3]
# Index: []
#
# [0 rows x 74 columns]
# Empty DataFrame
# Columns: [USAGE, NOM_TYPOLOGIE, PERIODE, TERRITOIRE, DISPOSITIF, PORTEUR, ISOLANT, REVETEMENT_EXT, REVETEMENT_INT, EP_PORTEUR, EP_ISOLANT, EP_RE, EP_RI, DISPOSITIF_MUR_OPTION1, DISPOSITIF_MUR_OPTION2, DISPOSITIF_MUR_OPTION3, DISPOSITIF_TOIT_OPTION2, DISPOSTIIF_TOIT_ OPTION1, PORTEUR1, PORTEUR2, PORTEUR4, REVETEMENT_EXT1, REVETEMENT_EXT2, REVETEMENT_EXT4, REVETEMENT_INT1, REVETEMENT_INT2, REVETEMENT_INT4, DISPOSITIF1, DISPOSITIF2, DISPOSITIF4, EP_ISOLANT1, EP_ISOLANT2, EP_ISOLANT4, EP_PORTEUR1, EP_PORTEUR2, EP_PORTEUR4, EP_RE1, EP_RE2, EP_RE4, EP_RI1, EP_RI2, EP_RI4, ISOLANT1, ISOLANT2, ISOLANT4, TERRITOIRE1, TERRITOIRE_DESC, TERRITOIRE_SHORT_ID, NUMERO_PERIODE, DATES, DATE_DEBUT, DATE_FIN, TYPE_VITRAGE, POURCENTAGE_VITRAGE, PROTECTIONS_SOLAIRES, VENTILATION, PERMEABILITE, COMPACITE, COUVERTURE_ROUTE, PLANCHER_INTERMEDIAIRE, EP_PLANCHER_RDC, EP_PLANCHER_INTER, ID_PLANCHER, PLANCHER_RDC, PLANCHER, DISPOSITIF3, PORTEUR3, ISOLANT3, REVETEMENT_EXT3, REVETEMENT_INT3, EP_PORTEUR3, EP_ISOLANT3, EP_RE3, EP_RI3]
# Index: []
#
# [0 rows x 74 columns]
# Empty DataFrame
# Columns: [USAGE, NOM_TYPOLOGIE, PERIODE, TERRITOIRE, DISPOSITIF, PORTEUR, ISOLANT, REVETEMENT_EXT, REVETEMENT_INT, EP_PORTEUR, EP_ISOLANT, EP_RE, EP_RI, DISPOSITIF_MUR_OPTION1, DISPOSITIF_MUR_OPTION2, DISPOSITIF_MUR_OPTION3, DISPOSITIF_TOIT_OPTION2, DISPOSTIIF_TOIT_ OPTION1, PORTEUR1, PORTEUR2, PORTEUR4, REVETEMENT_EXT1, REVETEMENT_EXT2, REVETEMENT_EXT4, REVETEMENT_INT1, REVETEMENT_INT2, REVETEMENT_INT4, DISPOSITIF1, DISPOSITIF2, DISPOSITIF4, EP_ISOLANT1, EP_ISOLANT2, EP_ISOLANT4, EP_PORTEUR1, EP_PORTEUR2, EP_PORTEUR4, EP_RE1, EP_RE2, EP_RE4, EP_RI1, EP_RI2, EP_RI4, ISOLANT1, ISOLANT2, ISOLANT4, TERRITOIRE1, TERRITOIRE_DESC, TERRITOIRE_SHORT_ID, NUMERO_PERIODE, DATES, DATE_DEBUT, DATE_FIN, TYPE_VITRAGE, POURCENTAGE_VITRAGE, PROTECTIONS_SOLAIRES, VENTILATION, PERMEABILITE, COMPACITE, COUVERTURE_ROUTE, PLANCHER_INTERMEDIAIRE, EP_PLANCHER_RDC, EP_PLANCHER_INTER, ID_PLANCHER, PLANCHER_RDC, PLANCHER, DISPOSITIF3, PORTEUR3, ISOLANT3, REVETEMENT_EXT3, REVETEMENT_INT3, EP_PORTEUR3, EP_ISOLANT3, EP_RE3, EP_RI3]
# Index: []
#
# [0 rows x 74 columns]

# %% [markdown]
# ##### Case REL
#
#  IMM_M_P4_TN_BB and REL_I_P3_TF

# %%
danube.loc[["REL_I_P3_TF"]]
# Out:
#                                USAGE NOM_TYPOLOGIE PERIODE TERRITOIRE  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF       BATIMENT RELIGIEUX             I      P3     FRANCE
#
#                       DISPOSITIF       PORTEUR  ISOLANT REVETEMENT_EXT  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
#
#                   REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                              ...
# REL_I_P3_TF       CONTRE CLOISON          40  ...
#
#                                           PLANCHER     DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF       DALLE BETON SUR TERRE PLEIN8NON0  HAB_T_P3_TN_GR
#
#                      PORTEUR3 ISOLANT3 REVETEMENT_EXT3 REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF       DALLE BETON      NON         GRAVIER             NON
#
#                  EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# REL_I_P3_TF               20           0    5.0    0.0
#
# [1 rows x 74 columns]

# %%
danube[danube.DISPOSITIF == "IMM_M_P4_TN_BB"]
# This dispositif is applied mostly to P4 archétypes, with exception to this one
# Out:
#                                USAGE NOM_TYPOLOGIE PERIODE      TERRITOIRE  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF       BATIMENT RELIGIEUX             I      P3          FRANCE
# SAN_I_P4_TF        BATIMENT DE SANTE             I      P4          FRANCE
# SAN_I_P4_TAR       BATIMENT DE SANTE             I      P4  FRANCE_ARDOISE
# SAN_I_P4_TBR       BATIMENT DE SANTE             I      P4    FRANCE_TUILE
# REL_I_P4_TF       BATIMENT RELIGIEUX             I      P4          FRANCE
# COM_I_P4_TF                 COMMERCE             I      P4          FRANCE
# HAB_I_P4_TF                  HABITAT             I      P4          FRANCE
# HAB_I_P4_TAR                 HABITAT             I      P4  FRANCE_ARDOISE
# HAB_I_P4_TBR                 HABITAT             I      P4    FRANCE_TUILE
# TER_I_P4_TF                TERTIAIRE             I      P4          FRANCE
#
#                       DISPOSITIF       PORTEUR  ISOLANT REVETEMENT_EXT  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# SAN_I_P4_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# SAN_I_P4_TAR      IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# SAN_I_P4_TBR      IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# REL_I_P4_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# COM_I_P4_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# HAB_I_P4_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# HAB_I_P4_TAR      IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# HAB_I_P4_TBR      IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
# TER_I_P4_TF       IMM_M_P4_TN_BB  BETON BANCHE  ITI_AIR         ENDUIT
#
#                   REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                              ...
# REL_I_P3_TF       CONTRE CLOISON          40  ...
# SAN_I_P4_TF       CONTRE CLOISON          40  ...
# SAN_I_P4_TAR      CONTRE CLOISON          40  ...
# SAN_I_P4_TBR      CONTRE CLOISON          40  ...
# REL_I_P4_TF       CONTRE CLOISON          40  ...
# COM_I_P4_TF       CONTRE CLOISON          40  ...
# HAB_I_P4_TF       CONTRE CLOISON          40  ...
# HAB_I_P4_TAR      CONTRE CLOISON          40  ...
# HAB_I_P4_TBR      CONTRE CLOISON          40  ...
# TER_I_P4_TF       CONTRE CLOISON          40  ...
#
#                                              PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF          DALLE BETON SUR TERRE PLEIN8NON0   HAB_T_P3_TN_GR
# SAN_I_P4_TF       DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_TU
# SAN_I_P4_TAR      DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P4_TPI_AR
# SAN_I_P4_TBR      DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_TU
# REL_I_P4_TF          DALLE BETON SUR TERRE PLEIN8NON0   HAB_T_P4_TN_GR
# COM_I_P4_TF       DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_GR
# HAB_I_P4_TF       DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_TU
# HAB_I_P4_TAR      DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P4_TPI_AR
# HAB_I_P4_TBR      DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_TU
# TER_I_P4_TF       DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_GR
#
#                         PORTEUR3 ISOLANT3 REVETEMENT_EXT3   REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# REL_I_P3_TF          DALLE BETON      NON         GRAVIER               NON
# SAN_I_P4_TF       STRUCTURE BOIS   ITI_LM           TUILE  PLAQUE DE PLATRE
# SAN_I_P4_TAR      STRUCTURE BOIS   ITI_LM         ARDOISE  PLAQUE DE PLATRE
# SAN_I_P4_TBR      STRUCTURE BOIS   ITI_LM           TUILE  PLAQUE DE PLATRE
# REL_I_P4_TF          DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
# COM_I_P4_TF          DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
# HAB_I_P4_TF       STRUCTURE BOIS   ITI_LM           TUILE  PLAQUE DE PLATRE
# HAB_I_P4_TAR      STRUCTURE BOIS   ITI_LM         ARDOISE  PLAQUE DE PLATRE
# HAB_I_P4_TBR      STRUCTURE BOIS   ITI_LM           TUILE  PLAQUE DE PLATRE
# TER_I_P4_TF          DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
#
#                  EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# REL_I_P3_TF               20           0    5.0    0.0
# SAN_I_P4_TF                0          12    2.0    1.3
# SAN_I_P4_TAR               0          12    2.0    1.3
# SAN_I_P4_TBR               0          12    2.0    1.3
# REL_I_P4_TF               20          12    5.0    1.3
# COM_I_P4_TF               20          12    5.0    1.3
# HAB_I_P4_TF                0          12    2.0    1.3
# HAB_I_P4_TAR               0          12    2.0    1.3
# HAB_I_P4_TBR               0          12    2.0    1.3
# TER_I_P4_TF               20          12    5.0    1.3
#
# [10 rows x 74 columns]

# %%
df[df.DISPOSITIF.str.startswith("IMM_M_P3")]
# There is not an exact match in P3
# Out:
#              DISPOSITIF         PORTEUR  EP_PORTEUR  ISOLANT  EP_ISOLANT  \
# 77         IMM_M_P3_TBR   BRIQUE CREUSE          25  ITI_AIR           1
# 78     IMM_M_P3_TN_BEPP    BETON BANCHE          20   ITE_LM           6
# 79   IMM_M_P3_TN_COM_BE  OSSATURE BETON           0      NON           0
# 80       IMM_M_P3_TN_PA        PARPAING          20  ITI_AIR           1
# 81   IMM_M_P3_TN_REL_BA      BETON ARME          25      NON           0
# 82  IMM_M_P3_TN_SCO_PRE  OSSATURE BETON           0      NON           0
# 83         IMM_M_P3_TPI        PARPAING          25      NON           0
#
#       REVETEMENT_INT  EP_RI       REVETEMENT_EXT  EP_RE
# 77    CONTRE CLOISON    1.3     PLAQUETTE BRIQUE      2
# 78  PLAQUE DE PLATRE    1.3        PANNEAU_PREFA     15
# 79  PLAQUE DE PLATRE    1.3        PANNEAU BETON     15
# 80    CONTRE CLOISON    1.3               ENDUIT      2
# 81           ENDUIT     1.0               ENDUIT      2
# 82               NON    0.0  PANNEAU PREFA BETON     15
# 83    CONTRE CLOISON    1.3               PIERRE     20

# %%
df[df.DISPOSITIF == "IMM_M_P4_TN_BB"]
# Out:
#         DISPOSITIF       PORTEUR  EP_PORTEUR  ISOLANT  EP_ISOLANT  \
# 86  IMM_M_P4_TN_BB  BETON BANCHE          40  ITI_AIR           1
#
#     REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 86  CONTRE CLOISON    1.3         ENDUIT      2

# %% [markdown]
# - Create IMM_M_P3_TN_BB replicating IMM_M_P4_TN_BB

# %% [markdown]
# ### Combinations
# - In order to calculate the Umur we need to define Umur0
# - Some standard values are given for Umur0 in 3CL
# - We need to associate each dispositif Danube with a corresponding 3CL option, or to make assumptions for the cases the materials are not described in their methodology.

# %%
materials_3cl = ["Murs en pierre de taille et moellons avec un seul matériau",
               "Murs en pierre de taille et moellons avec remplissage tout venant",
               "Murs en pisé ou béton de terre stabilisé (à partir d’argile crue)",
               "Murs en pans de bois sans remplissage tout venant",
               "Murs en pans de bois avec remplissage tout venant",
               "Murs bois (rondins)",
               "Murs en briques pleines simples",
               "Murs en briques pleines doubles avec lame d’air",
               "Murs en briques creuses",
               "Murs en blocs de béton pleins",
               "Murs en blocs de béton creux",
               "Murs en béton banché",
               "Murs en béton de mâchefer",
               "Monomur terre cuite",
               "Béton cellulaire",
               "Cloison de plâtre",
               "Non répertoriés"]

# %%
for col in df.columns[1:]:
    print(col,"\n", df[col].unique(),"\n")
# Out:
# PORTEUR
#  ['OSSATURE METALLIQUE' 'OSSATURE BETON' 'OSSATURE BOIS' 'TERRE CUITE'
#  'TERRE CRUE' 'BETON BANCHE' 'OSS_BETON' 'PARPAING' 'BRIQUE CREUSE'
#  'MONOMUR' 'AGGLOMERE DE BETON' 'STRUCTURE BOIS' 'DALLE BETON'
#  'BRIQUE PLEINE' 'PIERRE' 'GRANITE' 'GRES' 'MEULIERE' 'SCHISTE'
#  'VOLCANIQUE' 'BETON ARME' 'VOILE BETON' 'BETON' 'ND' 'BOIS' 'BAUGE'
#  'PISE' 'ARGILE' 'CALCAIRE' 'GALET' 'GNEISS']
#
# EP_PORTEUR
#  [  0  50  40  25  20  30  37  15  60  90  80 100  70  35]
#
# ISOLANT
#  ['NON' 'IR' 'ITI_LM' 'NON ' 'ITE_LM' 'ITI_LAINE MINERALE' 'OUI' 'ITI_AIR'
#  'ND' 'ITI']
#
# EP_ISOLANT
#  [ 0  5 10  6 12 15 20  1 16]
#
# REVETEMENT_INT
#  ['NON' 'PLAQUE DE PLATRE' 'BOIS' 'ENDUIT' 'CONTRE CLOISON'
#  'plaque de platre' 'ENDUIT ' 'ND']
#
# EP_RI
#  [ 0.   1.3 10.   2.   4.   1. ]
#
# REVETEMENT_EXT
#  ['PANNEAU SANDWICH' 'PANNEAU BETON' 'MUR RIDEAU VERRE' 'MUR RIDEAU VERRE '
#  'PIERRE' 'PIERRE BOIS' 'BARDAGE BOIS' 'ENDUIT' 'PANNEAU_PREFA'
#  'PANNEAU PREFA' 'BOIS' 'TUILE CANAL' 'TUILE MECANIQUE' 'TUILE PLATE'
#  'TUILE ROMAINE' 'TUILE' 'ARDOISE' 'LAUZE' 'GRAVIER' 'TUILE ' 'BRIQUE'
#  'TORCHIS' 'NON' 'PANNEAU PREFA BETON' 'PLAQUETTE BRIQUE' 'ENDUIT '
#  'BARDAGE METAL' 'ND' 'PIERRE ' 'SIMPLE VITRAGE' 'DOUBLE VITRAGE']
#
# EP_RE
#  [ 5  6 10 12 16 15 25 20  2  1 30  0 50 40  3]

# %% [markdown]
# ##### Change !

# %% [markdown]
# ###### ISOLANT

# %%
df[df["ISOLANT"] == 'ITI_LAINE MINERALE']
# change to ITI_LM
# Out:
#         DISPOSITIF        PORTEUR  EP_PORTEUR             ISOLANT  EP_ISOLANT  \
# 27  HAB_M_P5_TN_BC  BRIQUE CREUSE          25  ITI_LAINE MINERALE           5
#
#     REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 27  CONTRE CLOISON    1.3         ENDUIT      2

# %%
df[df["ISOLANT"] == 'ITI']
# change to ITI_LM
# Out:
#          DISPOSITIF        PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 140  PAV_M_P7_TN_BR  BRIQUE CREUSE          20     ITI          16
#
#        REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 140  PLAQUE DE PLATRE    1.3         ENDUIT      1

# %%
df[df["ISOLANT"] == 'OUI']
# change to ITI_LM
# Out:
#          DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 49   HAB_T_P4_TN_GR     DALLE BETON          20     OUI          12
# 50   HAB_T_P4_TN_TU  STRUCTURE BOIS          15     OUI          12
# 51  HAB_T_P4_TPI_AR  STRUCTURE BOIS          15     OUI          12
# 52  HAB_T_P5_TBR_TC  STRUCTURE BOIS          15     OUI          15
# 53   HAB_T_P5_TN_GR     DALLE BETON          20     OUI          15
# 54   HAB_T_P5_TN_TU  STRUCTURE BOIS          15     OUI          15
# 55  HAB_T_P5_TPI_AR  STRUCTURE BOIS          15     OUI          15
# 56  HAB_T_P6_TBR_TC  STRUCTURE BOIS          15     OUI          20
# 57   HAB_T_P6_TN_GR     DALLE BETON          20     OUI          20
# 58   HAB_T_P6_TN_TU  STRUCTURE BOIS          15     OUI          20
# 59  HAB_T_P6_TPI_AR  STRUCTURE BOIS          15     OUI          20
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 49  plaque de platre    1.3        GRAVIER      5
# 50  plaque de platre    1.3          TUILE      2
# 51  plaque de platre    1.3        ARDOISE      2
# 52  plaque de platre    1.3    TUILE CANAL      2
# 53  plaque de platre    1.3        GRAVIER      5
# 54  plaque de platre    1.3          TUILE      2
# 55  plaque de platre    1.3        ARDOISE      2
# 56  plaque de platre    1.3    TUILE CANAL      2
# 57  plaque de platre    1.3        GRAVIER      5
# 58  plaque de platre    1.3          TUILE      2
# 59  plaque de platre    1.3        ARDOISE      2

# %%
df[df["ISOLANT"] == 'NON ']
# change to 'NON'
# Out:
#           DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 21  HAB_M_P2_TN_BEPP       OSS_BETON          25    NON            0
# 72  IMM_M_P2_TN_BEPP  OSSATURE BETON           0    NON            0
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 21    CONTRE CLOISON    1.3  PANNEAU_PREFA     15
# 72  PLAQUE DE PLATRE    1.3  PANNEAU_PREFA     15

# %%
df.groupby(["ISOLANT"]).size().reset_index().rename(columns={0:'count'}).sort_values("count")
# Out:
#               ISOLANT  count
# 2                 ITI      1
# 4  ITI_LAINE MINERALE      1
# 6                  ND      1
# 8                NON       2
# 3             ITI_AIR      5
# 1              ITE_LM      8
# 9                 OUI     11
# 0                  IR     15
# 5              ITI_LM     20
# 7                 NON     86

# %% [markdown]
# ###### REVETEMENT_EXT

# %%
df[df["REVETEMENT_EXT"] == 'MUR RIDEAU VERRE ']
# change to 'MUR RIDEAU VERRE'
# Out:
#             DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 10  BGH_M_P5_TN_TER_MR  OSSATURE BETON           0      IR           0
#
#    REVETEMENT_INT  EP_RI     REVETEMENT_EXT  EP_RE
# 10            NON    0.0  MUR RIDEAU VERRE      10

# %%
df[df["REVETEMENT_EXT"] == 'ENDUIT ']
# change to 'ENDUIT'
# Out:
#             DISPOSITIF      PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 89  IMM_M_P4_TN_REL_BA   BETON ARME          30     NON           0
# 93  IMM_M_P5_TN_REL_VB  VOILE BETON          50     NON           0
# 96  IMM_M_P6_TN_REL_VB  VOILE BETON          50     NON           0
#
#    REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 89         ENDUIT    1.0        ENDUIT       2
# 93            NON    0.0        ENDUIT       2
# 96            NON    0.0        ENDUIT       2

# %%
# actually in disp toit
df[df["REVETEMENT_EXT"] == 'TUILE ']
# change to 'TUILE'
# Out:
#         DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 46  HAB_T_P3_TN_TU  STRUCTURE BOIS          15     NON           0
#
#    REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 46            NON    0.0         TUILE       2

# %%
df[df["REVETEMENT_EXT"] == 'PIERRE ']
# change to 'PIERRE'
# Out:
#           DISPOSITIF        PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 108  PAV_M_P1_TBo_sp  OSSATURE BOIS           0     NON           0
#
#     REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 108            NON    0.0        PIERRE      40

# %% [markdown]
# **Prefabriqué béton**

# %%
df[df["REVETEMENT_EXT"] == 'PANNEAU PREFA BETON']
# change to 'PANNEAU PREFA BETON'
# Out:
#              DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 76  IMM_M_P2_TN_SCO_PRE  OSSATURE BETON           0     NON           0
# 82  IMM_M_P3_TN_SCO_PRE  OSSATURE BETON           0     NON           0
#
#    REVETEMENT_INT  EP_RI       REVETEMENT_EXT  EP_RE
# 76            NON    0.0  PANNEAU PREFA BETON     15
# 82            NON    0.0  PANNEAU PREFA BETON     15

# %%
df[df["REVETEMENT_EXT"] == 'PANNEAU_PREFA']
# change to 'PANNEAU PREFA BETON'
# Out:
#           DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 25  HAB_M_P4_TN_PREF       OSS_BETON          25  ITE_LM          10
# 88  IMM_M_P4_TN_PREF  OSSATURE BETON           0  ITE_LM           6
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 25    CONTRE CLOISON    1.3  PANNEAU PREFA     15
# 88  PLAQUE DE PLATRE    1.3  PANNEAU PREFA     15

# %%
df[df["REVETEMENT_EXT"] == 'PANNEAU PREFA']
# change to 'PANNEAU PREFA BETON'
# Out:
#           DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 25  HAB_M_P4_TN_PREF       OSS_BETON          25  ITE_LM          10
# 88  IMM_M_P4_TN_PREF  OSSATURE BETON           0  ITE_LM           6
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 25    CONTRE CLOISON    1.3  PANNEAU PREFA     15
# 88  PLAQUE DE PLATRE    1.3  PANNEAU PREFA     15

# %%
df[df["REVETEMENT_EXT"] == 'PANNEAU BETON']
# change to 'PANNEAU PREFA BETON'
# Out:
#                DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 6   BGH_M_P2_TN_HAB_BE_BE  OSSATURE BETON           0     NON           0
# 7   BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM           5
# 9   BGH_M_P5_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM          10
# 73     IMM_M_P2_TN_COM_BE  OSSATURE BETON           0     NON           0
# 79     IMM_M_P3_TN_COM_BE  OSSATURE BETON           0     NON           0
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 6   PLAQUE DE PLATRE    1.3  PANNEAU BETON     15
# 7   PLAQUE DE PLATRE    1.3  PANNEAU BETON     15
# 9   PLAQUE DE PLATRE    1.3  PANNEAU BETON     15
# 73  PLAQUE DE PLATRE    1.3  PANNEAU BETON     15
# 79  PLAQUE DE PLATRE    1.3  PANNEAU BETON     15

# %% [markdown]
# ###### PORTEUR

# %%
df[df["PORTEUR"] == 'OSS_BETON']
# change to 'OSSATURE BETON'
# Out:
#           DISPOSITIF    PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 21  HAB_M_P2_TN_BEPP  OSS_BETON          25    NON            0
# 25  HAB_M_P4_TN_PREF  OSS_BETON          25  ITE_LM          10
#
#     REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 21  CONTRE CLOISON    1.3  PANNEAU_PREFA     15
# 25  CONTRE CLOISON    1.3  PANNEAU PREFA     15

# %%
df[df["PORTEUR"] == 'ND']
# check why
# Out:
#     DISPOSITIF PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT REVETEMENT_INT  EP_RI  \
# 105         ND      ND           0      ND           0             ND    0.0
#
#     REVETEMENT_EXT  EP_RE
# 105             ND      0

# %% [markdown]
# ###### REVETEMENT_INT

# %%
df[df["REVETEMENT_INT"] == 'ENDUIT ']
# Out:
#             DISPOSITIF     PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 81  IMM_M_P3_TN_REL_BA  BETON ARME          25     NON           0
#
#    REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 81        ENDUIT     1.0         ENDUIT      2

# %%
df[df["REVETEMENT_INT"] == 'plaque de platre' ]
# Out:
#          DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 48  HAB_T_P4_TBR_TC  STRUCTURE BOIS          15  ITI_LM          12
# 49   HAB_T_P4_TN_GR     DALLE BETON          20     OUI          12
# 50   HAB_T_P4_TN_TU  STRUCTURE BOIS          15     OUI          12
# 51  HAB_T_P4_TPI_AR  STRUCTURE BOIS          15     OUI          12
# 52  HAB_T_P5_TBR_TC  STRUCTURE BOIS          15     OUI          15
# 53   HAB_T_P5_TN_GR     DALLE BETON          20     OUI          15
# 54   HAB_T_P5_TN_TU  STRUCTURE BOIS          15     OUI          15
# 55  HAB_T_P5_TPI_AR  STRUCTURE BOIS          15     OUI          15
# 56  HAB_T_P6_TBR_TC  STRUCTURE BOIS          15     OUI          20
# 57   HAB_T_P6_TN_GR     DALLE BETON          20     OUI          20
# 58   HAB_T_P6_TN_TU  STRUCTURE BOIS          15     OUI          20
# 59  HAB_T_P6_TPI_AR  STRUCTURE BOIS          15     OUI          20
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 48  plaque de platre    1.3    TUILE CANAL      2
# 49  plaque de platre    1.3        GRAVIER      5
# 50  plaque de platre    1.3          TUILE      2
# 51  plaque de platre    1.3        ARDOISE      2
# 52  plaque de platre    1.3    TUILE CANAL      2
# 53  plaque de platre    1.3        GRAVIER      5
# 54  plaque de platre    1.3          TUILE      2
# 55  plaque de platre    1.3        ARDOISE      2
# 56  plaque de platre    1.3    TUILE CANAL      2
# 57  plaque de platre    1.3        GRAVIER      5
# 58  plaque de platre    1.3          TUILE      2
# 59  plaque de platre    1.3        ARDOISE      2

# %% [markdown]
# #### Materials

# %%
# In comparison with the roofs, there are much more variety of walls 
df.groupby(["PORTEUR"]).size().reset_index().rename(columns={0:'count'})
# Out:
#                 PORTEUR  count
# 0    AGGLOMERE DE BETON      1
# 1                ARGILE      1
# 2                 BAUGE      1
# 3                 BETON      1
# 4            BETON ARME      3
# 5          BETON BANCHE     10
# 6                  BOIS      1
# 7         BRIQUE CREUSE     18
# 8         BRIQUE PLEINE      2
# 9              CALCAIRE      1
# 10          DALLE BETON      5
# 11                GALET      1
# 12               GNEISS      1
# 13              GRANITE      2
# 14                 GRES      2
# 15             MEULIERE      2
# 16              MONOMUR      3
# 17                   ND      1
# 18       OSSATURE BETON     17
# 19        OSSATURE BOIS      9
# 20  OSSATURE METALLIQUE     15
# 21            OSS_BETON      2
# 22             PARPAING     14
# 23               PIERRE      2
# 24                 PISE      1
# 25              SCHISTE      2
# 26       STRUCTURE BOIS     23
# 27           TERRE CRUE      2
# 28          TERRE CUITE      2
# 29          VOILE BETON      3
# 30           VOLCANIQUE      2

# %%
# There are 79 different combinations of materials of walls
danube_wall_materials = df.groupby(["PORTEUR","REVETEMENT_INT","REVETEMENT_EXT"]).size().reset_index().rename(columns={0:'count'})
danube_wall_materials.to_excel("danube_wall_materials.xlsx")
danube_wall_materials
# Out:
#                PORTEUR    REVETEMENT_INT REVETEMENT_EXT  count
# 0   AGGLOMERE DE BETON    CONTRE CLOISON         ENDUIT      1
# 1               ARGILE            ENDUIT            NON      1
# 2                BAUGE            ENDUIT         ENDUIT      1
# 3                BETON  PLAQUE DE PLATRE  BARDAGE METAL      1
# 4           BETON ARME            ENDUIT         ENDUIT      1
# ..                 ...               ...            ...    ...
# 74         TERRE CUITE            ENDUIT         ENDUIT      2
# 75         VOILE BETON               NON        ENDUIT       2
# 76         VOILE BETON  PLAQUE DE PLATRE         ENDUIT      1
# 77          VOLCANIQUE            ENDUIT            NON      1
# 78          VOLCANIQUE               NON            NON      1
#
# [79 rows x 4 columns]

# %%
df[df["REVETEMENT_EXT"]=="BARDAGE METAL"]
# Out:
#             DISPOSITIF PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 99  IMM_M_P7_TN_TER_BE   BETON          20  ITE_LM          16
#
#       REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 99  PLAQUE DE PLATRE    1.3  BARDAGE METAL      2

# %%
danube[danube["DISPOSITIF"]=="IMM_M_P7_TN_TER_BE"]
# Out:
#                                     USAGE NOM_TYPOLOGIE PERIODE  \
# NUMERO_TYPOLOGIE
# SCO_I_P7_TF       BATIMENT D ENSEIGNEMENT             I      P7
# SCO_I_P7_TAR      BATIMENT D ENSEIGNEMENT             I      P7
# SCO_I_P7_TBR      BATIMENT D ENSEIGNEMENT             I      P7
# SAN_I_P7_TAR            BATIMENT DE SANTE             I      P7
# COM_I_P7_TF                      COMMERCE             I      P7
#
#                       TERRITOIRE          DISPOSITIF PORTEUR ISOLANT  \
# NUMERO_TYPOLOGIE
# SCO_I_P7_TF               FRANCE  IMM_M_P7_TN_TER_BE   BETON  ITE_LM
# SCO_I_P7_TAR      FRANCE_ARDOISE  IMM_M_P7_TN_TER_BE   BETON  ITE_LM
# SCO_I_P7_TBR        FRANCE_TUILE  IMM_M_P7_TN_TER_BE   BETON  ITE_LM
# SAN_I_P7_TAR      FRANCE_ARDOISE  IMM_M_P7_TN_TER_BE   BETON  ITE_LM
# COM_I_P7_TF               FRANCE  IMM_M_P7_TN_TER_BE   BETON  ITE_LM
#
#                  REVETEMENT_EXT    REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                                               ...
# SCO_I_P7_TF       BARDAGE METAL  PLAQUE DE PLATRE          20  ...
# SCO_I_P7_TAR      BARDAGE METAL  PLAQUE DE PLATRE          20  ...
# SCO_I_P7_TBR      BARDAGE METAL  PLAQUE DE PLATRE          20  ...
# SAN_I_P7_TAR      BARDAGE METAL  PLAQUE DE PLATRE          20  ...
# COM_I_P7_TF       BARDAGE METAL  PLAQUE DE PLATRE          20  ...
#
#                                              PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# SCO_I_P7_TF       DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P7_TBR_TC
# SCO_I_P7_TAR      DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P7_TPI_AR
# SCO_I_P7_TBR      DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P7_TBR_TC
# SAN_I_P7_TAR      DALLE BETON SOUS SOL20DALLE BETON15  HAB_T_P7_TPI_AR
# COM_I_P7_TF       DALLE BETON SOUS SOL20DALLE BETON15      HAB_T_P7_TN
#
#                         PORTEUR3 ISOLANT3 REVETEMENT_EXT3   REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# SCO_I_P7_TF       STRUCTURE BOIS   ITI_LM           TUILE  PLAQUE DE PLATRE
# SCO_I_P7_TAR      STRUCTURE BOIS   ITI_LM         ARDOISE  PLAQUE DE PLATRE
# SCO_I_P7_TBR      STRUCTURE BOIS   ITI_LM           TUILE  PLAQUE DE PLATRE
# SAN_I_P7_TAR      STRUCTURE BOIS   ITI_LM         ARDOISE  PLAQUE DE PLATRE
# COM_I_P7_TF          DALLE BETON  ITE_POL         GRAVIER               NON
#
#                  EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# SCO_I_P7_TF                0          30    2.0    1.3
# SCO_I_P7_TAR               0          30    2.0    1.3
# SCO_I_P7_TBR               0          30    2.0    1.3
# SAN_I_P7_TAR               0          30    2.0    1.3
# COM_I_P7_TF               20          30   10.0    0.0
#
# [5 rows x 74 columns]

# %% [markdown]
# #### Ossatures

# %% [markdown]
# ##### Ossature metallique

# %%
df[(df.PORTEUR =='OSSATURE METALLIQUE')].groupby("REVETEMENT_EXT").size()
# Out:
# REVETEMENT_EXT
# DOUBLE VITRAGE      3
# MUR RIDEAU VERRE    2
# PANNEAU SANDWICH    6
# SIMPLE VITRAGE      4
# dtype: int64

# %%
# "ossature métalique" can be associated with "panneau sandwich" for BA and with "mur rideau verre" for I
# panneau sandwich is not in 3CL list.
# I find strange they are not insulated, not even for sonoric purposes. Was it common in the past?
# Specially for periods after P3...
df[(df.PORTEUR =='OSSATURE METALLIQUE')&(~df.DISPOSITIF.str.startswith("SER")) ]
# Out:
#             DISPOSITIF              PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 0   BA_M_P2_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 1   BA_M_P3_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 2        BA_M_P4_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 3        BA_M_P5_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 4        BA_M_P6_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 5        BA_M_P7_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 95  IMM_M_P6_TN_TER_MR  OSSATURE METALLIQUE           0      IR           0
# 98  IMM_M_P7_TN_TER_MR  OSSATURE METALLIQUE           0      IR           0
#
#    REVETEMENT_INT  EP_RI    REVETEMENT_EXT  EP_RE period
# 0             NON    0.0  PANNEAU SANDWICH      5     P2
# 1             NON    0.0  PANNEAU SANDWICH      5     P3
# 2             NON    0.0  PANNEAU SANDWICH      6     P4
# 3             NON    0.0  PANNEAU SANDWICH     10     P5
# 4             NON    0.0  PANNEAU SANDWICH     12     P6
# 5             NON    0.0  PANNEAU SANDWICH     16     P7
# 95            NON    0.0  MUR RIDEAU VERRE     10     P6
# 98            NON    0.0  MUR RIDEAU VERRE     10     P7

# %%
danube[danube.DISPOSITIF == "IMM_M_P6_TN_TER_MR"]
# Out:
#                       USAGE NOM_TYPOLOGIE PERIODE TERRITOIRE  \
# NUMERO_TYPOLOGIE
# TER_I_P6_TF       TERTIAIRE             I      P6     FRANCE
#
#                           DISPOSITIF              PORTEUR ISOLANT  \
# NUMERO_TYPOLOGIE
# TER_I_P6_TF       IMM_M_P6_TN_TER_MR  OSSATURE METALLIQUE      IR
#
#                     REVETEMENT_EXT REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                                               ...
# TER_I_P6_TF       MUR RIDEAU VERRE            NON           0  ...
#
#                                              PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# TER_I_P6_TF       DALLE BETON SOUS SOL20DALLE BETON15  TER_T_P6_TN_BAC
#
#                          PORTEUR3 ISOLANT3 REVETEMENT_EXT3 REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# TER_I_P6_TF       STRUCTURE METAL   ITI_LM            TOLE             NON
#
#                  EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# TER_I_P6_TF                0          11    0.8    0.0
#
# [1 rows x 79 columns]

# %%
# all "serre" is with "ossature métalique"
# they won't be analysed
df[df.DISPOSITIF.str.startswith("SER")]
# Out:
#       DISPOSITIF              PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 143  SER_M_P1_TN  OSSATURE METALLIQUE           0     NON           0
# 144  SER_M_P2_TN  OSSATURE METALLIQUE           0     NON           0
# 145  SER_M_P3_TN  OSSATURE METALLIQUE           0     NON           0
# 146  SER_M_P4_TN  OSSATURE METALLIQUE           0     NON           0
# 147  SER_M_P5_TN  OSSATURE METALLIQUE           0     NON           0
# 148  SER_M_P6_TN  OSSATURE METALLIQUE           0     NON           0
# 149  SER_M_P7_TN  OSSATURE METALLIQUE           0     NON           0
#
#     REVETEMENT_INT  EP_RI  REVETEMENT_EXT  EP_RE
# 143            NON    0.0  SIMPLE VITRAGE      2
# 144            NON    0.0  SIMPLE VITRAGE      2
# 145            NON    0.0  SIMPLE VITRAGE      2
# 146            NON    0.0  SIMPLE VITRAGE      2
# 147            NON    0.0  DOUBLE VITRAGE      3
# 148            NON    0.0  DOUBLE VITRAGE      3
# 149            NON    0.0  DOUBLE VITRAGE      3

# %%
df[df.REVETEMENT_EXT=="PANNEAU SANDWICH"]
# Out:
#              DISPOSITIF              PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 0    BA_M_P2_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 1    BA_M_P3_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 2         BA_M_P4_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 3         BA_M_P5_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 4         BA_M_P6_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 5         BA_M_P7_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 90  IMM_M_P4_TN_SCO_PRE       OSSATURE BETON           0      IR           0
# 94  IMM_M_P5_TN_SCO_PRE       OSSATURE BETON           0      IR           0
#
#    REVETEMENT_INT  EP_RI    REVETEMENT_EXT  EP_RE
# 0             NON    0.0  PANNEAU SANDWICH      5
# 1             NON    0.0  PANNEAU SANDWICH      5
# 2             NON    0.0  PANNEAU SANDWICH      6
# 3             NON    0.0  PANNEAU SANDWICH     10
# 4             NON    0.0  PANNEAU SANDWICH     12
# 5             NON    0.0  PANNEAU SANDWICH     16
# 90            NON    0.0  PANNEAU SANDWICH      6
# 94            NON    0.0  PANNEAU SANDWICH     10

# %% [markdown]
# ##### Ossature béton

# %%
df[(df.PORTEUR =='OSSATURE BETON')].groupby(["REVETEMENT_EXT","REVETEMENT_INT"]).size()
# Out:
# REVETEMENT_EXT       REVETEMENT_INT
# MUR RIDEAU VERRE     NON                 5
# MUR RIDEAU VERRE     NON                 1
# PANNEAU BETON        PLAQUE DE PLATRE    5
# PANNEAU PREFA        PLAQUE DE PLATRE    1
# PANNEAU PREFA BETON  NON                 2
# PANNEAU SANDWICH     NON                 2
# PANNEAU_PREFA        PLAQUE DE PLATRE    1
# dtype: int64

# %%
df[(df.PORTEUR =='OSSATURE BETON')& (df.REVETEMENT_EXT.str.startswith("MUR"))]
# Out:
#             DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 8   BGH_M_P4_TN_TER_MR  OSSATURE BETON           0      IR           0
# 10  BGH_M_P5_TN_TER_MR  OSSATURE BETON           0      IR           0
# 11  BGH_M_P6_TN_HAB_MR  OSSATURE BETON           0      IR           0
# 12  BGH_M_P6_TN_TER_MR  OSSATURE BETON           0      IR           0
# 13  BGH_M_P7_TN_HAB_MR  OSSATURE BETON           0      IR           0
# 14  BGH_M_P7_TN_TER_MR  OSSATURE BETON           0      IR           0
#
#    REVETEMENT_INT  EP_RI     REVETEMENT_EXT  EP_RE
# 8             NON    0.0   MUR RIDEAU VERRE     10
# 10            NON    0.0  MUR RIDEAU VERRE      10
# 11            NON    0.0   MUR RIDEAU VERRE     10
# 12            NON    0.0   MUR RIDEAU VERRE     10
# 13            NON    0.0   MUR RIDEAU VERRE     10
# 14            NON    0.0   MUR RIDEAU VERRE     10

# %%
df[df.DISPOSITIF.str.startswith("BGH")]
# Out:
#                DISPOSITIF         PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 6   BGH_M_P2_TN_HAB_BE_BE  OSSATURE BETON           0     NON           0
# 7   BGH_M_P4_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM           5
# 8      BGH_M_P4_TN_TER_MR  OSSATURE BETON           0      IR           0
# 9   BGH_M_P5_TN_HAB_BE_BE  OSSATURE BETON           0  ITI_LM          10
# 10     BGH_M_P5_TN_TER_MR  OSSATURE BETON           0      IR           0
# 11     BGH_M_P6_TN_HAB_MR  OSSATURE BETON           0      IR           0
# 12     BGH_M_P6_TN_TER_MR  OSSATURE BETON           0      IR           0
# 13     BGH_M_P7_TN_HAB_MR  OSSATURE BETON           0      IR           0
# 14     BGH_M_P7_TN_TER_MR  OSSATURE BETON           0      IR           0
#
#       REVETEMENT_INT  EP_RI     REVETEMENT_EXT  EP_RE
# 6   PLAQUE DE PLATRE    1.3      PANNEAU BETON     15
# 7   PLAQUE DE PLATRE    1.3      PANNEAU BETON     15
# 8                NON    0.0   MUR RIDEAU VERRE     10
# 9   PLAQUE DE PLATRE    1.3      PANNEAU BETON     15
# 10               NON    0.0  MUR RIDEAU VERRE      10
# 11               NON    0.0   MUR RIDEAU VERRE     10
# 12               NON    0.0   MUR RIDEAU VERRE     10
# 13               NON    0.0   MUR RIDEAU VERRE     10
# 14               NON    0.0   MUR RIDEAU VERRE     10

# %%
danube[danube.DISPOSITIF.str.endswith("MR")]
# Out:
#                       USAGE NOM_TYPOLOGIE PERIODE TERRITOIRE  \
# NUMERO_TYPOLOGIE
# TER_IGH_P4_TF     TERTIAIRE           IGH      P4     FRANCE
# TER_IGH_P5_TF     TERTIAIRE           IGH      P5     FRANCE
# TER_I_P6_TF       TERTIAIRE             I      P6     FRANCE
# HAB_IGH_P6_TF       HABITAT           IGH      P6     FRANCE
# TER_IGH_P6_TF     TERTIAIRE           IGH      P6     FRANCE
# TER_I_P7_TF       TERTIAIRE             I      P7     FRANCE
# HAB_IGH_P7_TF       HABITAT           IGH      P7     FRANCE
# TER_IGH_P7_TF     TERTIAIRE           IGH      P7     FRANCE
#
#                           DISPOSITIF              PORTEUR ISOLANT  \
# NUMERO_TYPOLOGIE
# TER_IGH_P4_TF     BGH_M_P4_TN_TER_MR       OSSATURE BETON      IR
# TER_IGH_P5_TF     BGH_M_P5_TN_TER_MR       OSSATURE BETON      IR
# TER_I_P6_TF       IMM_M_P6_TN_TER_MR  OSSATURE METALLIQUE      IR
# HAB_IGH_P6_TF     BGH_M_P6_TN_TER_MR       OSSATURE BETON      IR
# TER_IGH_P6_TF     BGH_M_P6_TN_TER_MR       OSSATURE BETON      IR
# TER_I_P7_TF       IMM_M_P7_TN_TER_MR  OSSATURE METALLIQUE      IR
# HAB_IGH_P7_TF     BGH_M_P7_TN_HAB_MR       OSSATURE BETON      IR
# TER_IGH_P7_TF     BGH_M_P7_TN_TER_MR       OSSATURE BETON      IR
#
#                      REVETEMENT_EXT REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                                                ...
# TER_IGH_P4_TF      MUR RIDEAU VERRE            NON           0  ...
# TER_IGH_P5_TF     MUR RIDEAU VERRE             NON           0  ...
# TER_I_P6_TF        MUR RIDEAU VERRE            NON           0  ...
# HAB_IGH_P6_TF      MUR RIDEAU VERRE            NON           0  ...
# TER_IGH_P6_TF      MUR RIDEAU VERRE            NON           0  ...
# TER_I_P7_TF        MUR RIDEAU VERRE            NON           0  ...
# HAB_IGH_P7_TF      MUR RIDEAU VERRE            NON           0  ...
# TER_IGH_P7_TF      MUR RIDEAU VERRE            NON           0  ...
#
#                                              PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# TER_IGH_P4_TF     DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P4_TN_GR
# TER_IGH_P5_TF     DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P5_TN_GR
# TER_I_P6_TF       DALLE BETON SOUS SOL20DALLE BETON15  TER_T_P6_TN_BAC
# HAB_IGH_P6_TF     DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P6_TN_GR
# TER_IGH_P6_TF     DALLE BETON SOUS SOL20DALLE BETON15   HAB_T_P6_TN_GR
# TER_I_P7_TF       DALLE BETON SOUS SOL20DALLE BETON15      HAB_T_P7_TN
# HAB_IGH_P7_TF     DALLE BETON SOUS SOL20DALLE BETON15      HAB_T_P7_TN
# TER_IGH_P7_TF     DALLE BETON SOUS SOL20DALLE BETON15      HAB_T_P7_TN
#
#                          PORTEUR3 ISOLANT3 REVETEMENT_EXT3   REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# TER_IGH_P4_TF         DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
# TER_IGH_P5_TF         DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
# TER_I_P6_TF       STRUCTURE METAL   ITI_LM            TOLE               NON
# HAB_IGH_P6_TF         DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
# TER_IGH_P6_TF         DALLE BETON   ITI_LM         GRAVIER  PLAQUE DE PLATRE
# TER_I_P7_TF           DALLE BETON  ITE_POL         GRAVIER               NON
# HAB_IGH_P7_TF         DALLE BETON  ITE_POL         GRAVIER               NON
# TER_IGH_P7_TF         DALLE BETON  ITE_POL         GRAVIER               NON
#
#                  EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# TER_IGH_P4_TF             20          12    5.0    1.3
# TER_IGH_P5_TF             20          15    5.0    1.3
# TER_I_P6_TF                0          11    0.8    0.0
# HAB_IGH_P6_TF             20          20    5.0    1.3
# TER_IGH_P6_TF             20          20    5.0    1.3
# TER_I_P7_TF               20          30   10.0    0.0
# HAB_IGH_P7_TF             20          30   10.0    0.0
# TER_IGH_P7_TF             20          30   10.0    0.0
#
# [8 rows x 74 columns]

# %% [markdown]
# #### Autres

# %%
df[(df.PORTEUR =='BOIS')]
# Out:
#           DISPOSITIF PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT REVETEMENT_INT  \
# 110  PAV_M_P1_TBo-bo    BOIS          50      IR           0            NON
#
#      EP_RI REVETEMENT_EXT  EP_RE
# 110    0.0            NON      0

# %%
danube[danube["DISPOSITIF"]=="PAV_M_P1_TBo-bo"]
# Out:
#                                USAGE NOM_TYPOLOGIE PERIODE  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD  BATIMENT AGRICOLE            BA      P1
# AGR_BA_P1_TBO_TUI  BATIMENT AGRICOLE            BA      P1
# HAB_I_P1_TBO_ARD             HABITAT             I      P1
# HAB_I_P1_TBO_TUI             HABITAT             I      P1
# TER_I_P1_TBO_ARD           TERTIAIRE             I      P1
# TER_I_P1_TBO_TUI           TERTIAIRE             I      P1
# HAB_P_P1_TBO_ARD             HABITAT             P      P1
# HAB_P_P1_TBO_TUI             HABITAT             P      P1
#
#                             TERRITOIRE       DISPOSITIF PORTEUR ISOLANT  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD  FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# AGR_BA_P1_TBO_TUI    FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_I_P1_TBO_ARD   FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_I_P1_TBO_TUI     FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
# TER_I_P1_TBO_ARD   FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# TER_I_P1_TBO_TUI     FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_P_P1_TBO_ARD   FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_P_P1_TBO_TUI     FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
#
#                   REVETEMENT_EXT REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                                             ...
# AGR_BA_P1_TBO_ARD            NON            NON          50  ...
# AGR_BA_P1_TBO_TUI            NON            NON          50  ...
# HAB_I_P1_TBO_ARD             NON            NON          50  ...
# HAB_I_P1_TBO_TUI             NON            NON          50  ...
# TER_I_P1_TBO_ARD             NON            NON          50  ...
# TER_I_P1_TBO_TUI             NON            NON          50  ...
# HAB_P_P1_TBO_ARD             NON            NON          50  ...
# HAB_P_P1_TBO_TUI             NON            NON          50  ...
#
#                                                     PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD                          TERRE BATTUE1NON0  HAB_T_P1_TPI_AR
# AGR_BA_P1_TBO_TUI                          TERRE BATTUE1NON0  HAB_T_P1_TBR_TM
# HAB_I_P1_TBO_ARD   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TPI_AR
# HAB_I_P1_TBO_TUI   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TBR_TM
# TER_I_P1_TBO_ARD   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TPI_AR
# TER_I_P1_TBO_TUI   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TBR_TM
# HAB_P_P1_TBO_ARD             REVETEMENT SUR TERRE PLEIN4NON0  HAB_T_P1_TPI_AR
# HAB_P_P1_TBO_TUI             REVETEMENT SUR TERRE PLEIN4NON0  HAB_T_P1_TBR_TP
#
#                          PORTEUR3 ISOLANT3  REVETEMENT_EXT3 REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD  STRUCTURE BOIS      NON          ARDOISE             NON
# AGR_BA_P1_TBO_TUI  STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# HAB_I_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# HAB_I_P1_TBO_TUI   STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# TER_I_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# TER_I_P1_TBO_TUI   STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# HAB_P_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# HAB_P_P1_TBO_TUI   STRUCTURE BOIS      NON      TUILE PLATE             NON
#
#                   EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD           0           0    2.0    0.0
# AGR_BA_P1_TBO_TUI           0           0    2.0    0.0
# HAB_I_P1_TBO_ARD            0           0    2.0    0.0
# HAB_I_P1_TBO_TUI            0           0    2.0    0.0
# TER_I_P1_TBO_ARD            0           0    2.0    0.0
# TER_I_P1_TBO_TUI            0           0    2.0    0.0
# HAB_P_P1_TBO_ARD            0           0    2.0    0.0
# HAB_P_P1_TBO_TUI            0           0    2.0    0.0
#
# [8 rows x 74 columns]

# %%
df[(df.REVETEMENT_EXT.str.startswith("PIERRE"))&(df["PORTEUR"] == "OSSATURE BOIS")]
# Out:
#           DISPOSITIF        PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 15   HAB_M_P1_TBo_pi  OSSATURE BOIS           0     NON           0
# 16   HAB_M_P1_TBo_sp  OSSATURE BOIS           0     NON           0
# 107  PAV_M_P1_TBo_pi  OSSATURE BOIS           0     NON           0
# 108  PAV_M_P1_TBo_sp  OSSATURE BOIS           0     NON           0
#
#     REVETEMENT_INT  EP_RI REVETEMENT_EXT  EP_RE
# 15             NON    0.0         PIERRE     25
# 16             NON    0.0    PIERRE BOIS     20
# 107            NON    0.0         PIERRE     50
# 108            NON    0.0        PIERRE      40

# %%
danube[danube["DISPOSITIF"]=="PAV_M_P1_TBo-bo"]
# Out:
#                                USAGE NOM_TYPOLOGIE PERIODE  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD  BATIMENT AGRICOLE            BA      P1
# AGR_BA_P1_TBO_TUI  BATIMENT AGRICOLE            BA      P1
# HAB_I_P1_TBO_ARD             HABITAT             I      P1
# HAB_I_P1_TBO_TUI             HABITAT             I      P1
# TER_I_P1_TBO_ARD           TERTIAIRE             I      P1
# TER_I_P1_TBO_TUI           TERTIAIRE             I      P1
# HAB_P_P1_TBO_ARD             HABITAT             P      P1
# HAB_P_P1_TBO_TUI             HABITAT             P      P1
#
#                             TERRITOIRE       DISPOSITIF PORTEUR ISOLANT  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD  FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# AGR_BA_P1_TBO_TUI    FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_I_P1_TBO_ARD   FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_I_P1_TBO_TUI     FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
# TER_I_P1_TBO_ARD   FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# TER_I_P1_TBO_TUI     FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_P_P1_TBO_ARD   FRANCE_BOIS_ARDOISE  PAV_M_P1_TBo-bo    BOIS      IR
# HAB_P_P1_TBO_TUI     FRANCE_BOIS_TUILE  PAV_M_P1_TBo-bo    BOIS      IR
#
#                   REVETEMENT_EXT REVETEMENT_INT  EP_PORTEUR  ...  \
# NUMERO_TYPOLOGIE                                             ...
# AGR_BA_P1_TBO_ARD            NON            NON          50  ...
# AGR_BA_P1_TBO_TUI            NON            NON          50  ...
# HAB_I_P1_TBO_ARD             NON            NON          50  ...
# HAB_I_P1_TBO_TUI             NON            NON          50  ...
# TER_I_P1_TBO_ARD             NON            NON          50  ...
# TER_I_P1_TBO_TUI             NON            NON          50  ...
# HAB_P_P1_TBO_ARD             NON            NON          50  ...
# HAB_P_P1_TBO_TUI             NON            NON          50  ...
#
#                                                     PLANCHER      DISPOSITIF3  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD                          TERRE BATTUE1NON0  HAB_T_P1_TPI_AR
# AGR_BA_P1_TBO_TUI                          TERRE BATTUE1NON0  HAB_T_P1_TBR_TM
# HAB_I_P1_TBO_ARD   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TPI_AR
# HAB_I_P1_TBO_TUI   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TBR_TM
# TER_I_P1_TBO_ARD   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TPI_AR
# TER_I_P1_TBO_TUI   REVETEMENT SUR TERRE PLEIN4PLANCHER BOIS3  HAB_T_P1_TBR_TM
# HAB_P_P1_TBO_ARD             REVETEMENT SUR TERRE PLEIN4NON0  HAB_T_P1_TPI_AR
# HAB_P_P1_TBO_TUI             REVETEMENT SUR TERRE PLEIN4NON0  HAB_T_P1_TBR_TP
#
#                          PORTEUR3 ISOLANT3  REVETEMENT_EXT3 REVETEMENT_INT3  \
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD  STRUCTURE BOIS      NON          ARDOISE             NON
# AGR_BA_P1_TBO_TUI  STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# HAB_I_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# HAB_I_P1_TBO_TUI   STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# TER_I_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# TER_I_P1_TBO_TUI   STRUCTURE BOIS      NON  TUILE MECANIQUE             NON
# HAB_P_P1_TBO_ARD   STRUCTURE BOIS      NON          ARDOISE             NON
# HAB_P_P1_TBO_TUI   STRUCTURE BOIS      NON      TUILE PLATE             NON
#
#                   EP_PORTEUR3 EP_ISOLANT3 EP_RE3 EP_RI3
# NUMERO_TYPOLOGIE
# AGR_BA_P1_TBO_ARD           0           0    2.0    0.0
# AGR_BA_P1_TBO_TUI           0           0    2.0    0.0
# HAB_I_P1_TBO_ARD            0           0    2.0    0.0
# HAB_I_P1_TBO_TUI            0           0    2.0    0.0
# TER_I_P1_TBO_ARD            0           0    2.0    0.0
# TER_I_P1_TBO_TUI            0           0    2.0    0.0
# HAB_P_P1_TBO_ARD            0           0    2.0    0.0
# HAB_P_P1_TBO_TUI            0           0    2.0    0.0
#
# [8 rows x 74 columns]
