# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel(r"Dispositifs_mur.xlsx")

# %%
len(df)
# Out:
# 148

# %%
df
# Out:
#              DISPOSITIF              PORTEUR  EP_PORTEUR ISOLANT  EP_ISOLANT  \
# 0    BA_M_P2_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 1    BA_M_P3_TN_IND_TOL  OSSATURE METALLIQUE           0     NON           0
# 2         BA_M_P4_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 3         BA_M_P5_TN_PS  OSSATURE METALLIQUE           0      IR           0
# 4         BA_M_P6_TN_PS  OSSATURE METALLIQUE           0      IR           0
# ..                  ...                  ...         ...     ...         ...
# 143         SER_M_P3_TN  OSSATURE METALLIQUE           0     NON           0
# 144         SER_M_P4_TN  OSSATURE METALLIQUE           0     NON           0
# 145         SER_M_P5_TN  OSSATURE METALLIQUE           0     NON           0
# 146         SER_M_P6_TN  OSSATURE METALLIQUE           0     NON           0
# 147         SER_M_P7_TN  OSSATURE METALLIQUE           0     NON           0
#
# ...
